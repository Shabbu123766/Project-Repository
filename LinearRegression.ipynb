# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, r2_score

# %%
df = pd.read_csv("salarylpa.csv")

# %%
print("Dataset Preview")
print(df.head())
# Out:
# Dataset Preview
#    Experience_years  Salary_lpa
# 0               0.5         3.0
# 1               1.0         3.5
# 2               2.0         4.5
# 3               3.0         5.2
# 4               4.0         6.0

# %%
# step 3: define features and target
x = df[["Experience_years"]]
y = df["Salary_lpa"]

#step 4: split dataset
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42
)

#step 5: Train linear regression model
model = LinearRegression()
model.fit(x_train, y_train)

#step 6: Model parameters
print("\nSlope (m):", model.coef_[0])
print("Intercept (b):", model.intercept_)

#step 7: Predict on test data
y_pred = model.predict(x_test)

print("\nActual vs Predicted:")
for actual, pred in zip(y_test, y_pred):
  print(f"Actual: {actual:.2f}, Predicted: {pred:.2f}")

#step 8: Evaluate model
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("\nMean Absolute Error:", mae)
print("R2 Score:", r2)

#step 9: Predict new salary
new_salary = np.array([[1800]])
predicted_price = model.predict(new_salary)

print(f"\nPredicted salary based on Experienced years: Rs.{predicted_price[0]:.2f} lakhs")

#step 10: Visualization
plt.scatter(x, y, color="red", label="Actual Data")
plt.plot(x, model.predict(x), label="Regression Line")
plt.xlabel("Experience (years)")
plt.ylabel("Salary (lpa)")
plt.title("Salary Prediction using Linear Regression")
plt.legend()
plt.show()
# Out:
# Slope (m): 0.7623129251700681
# Intercept (b): 2.8900680272108836
#
# Actual vs Predicted:
# Actual: 6.80, Predicted: 6.70
# Actual: 3.00, Predicted: 3.27
# Actual: 10.50, Predicted: 10.51
#
# Mean Absolute Error: 0.1275963718820862
# R2 Score: 0.9970343792256637
#
# Predicted salary based on Experienced years: Rs.1375.05 lakhs
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
