# %%
# Scenario: Game Storyline Generator
# You’re designing a fantasy role‑playing game and need quick ideas for quests and dialogue.
# - The developer types a prompt:
# “The hero enters the ancient forest and discovers…”
# - The GPT‑2 pipeline continues the story:
# “The hero enters the ancient forest and discovers a hidden village where the people whisper of
#  a cursed artifact buried beneath the old ruins.”


# Import library
from transformers import pipeline

# Load GPT-2 model
story_generator = pipeline("text-generation", model="gpt2")

# Prompt for story
prompt = "The hero enters the ancient forest and discovers"

# Generate story
result = story_generator(prompt, max_length=60)

# Print generated story
print(result[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=60) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# The hero enters the ancient forest and discovers a large snake's head. The snake's head is made of a very simple bone and is covered in a bright green light. The hero is surprised by the glow of the snake's head and finds that the snake is actually a large fish. The hero is also shocked by the red light of the snake's head, which is quite bright. As the hero's heart changes into a red color, he is surprised by the red light of the snake's head. Afterwards the hero is shocked by even more red light of the snake's head, which is bright red. Upon realizing the red light of the snake's head, the hero is shocked by the light of the snake's head, which is red. After this, the hero is surprised by the red light of the snake's head, which is blue. After this, the hero is surprised by the blue light of the snake's head. After this, the hero is surprised by the blue light of the snake's head, which is white. After this, the hero is shocked by the red light of the snake's head, which is white. After this, the hero is shocked by the white light of the snake's head, which is red. After this, the hero is surprised by the red light of the
