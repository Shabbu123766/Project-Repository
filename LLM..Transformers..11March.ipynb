# %%
from google.colab import userdata

api_key = userdata.get('my_api_key')

print("API key loaded successfully")
# Out:
# API key loaded successfully

# %%
#  Scenario: AI‑Powered Email Assistant
# You’re building an email drafting assistant for a corporate team.
# - When a user starts typing:
# “Artificial Intelligence will…”
# - The assistant uses GPT‑2 to auto‑complete the sentence with a coherent continuation.
# - Example output:
# “Artificial Intelligence will transform the way businesses interact with customers,
# enabling faster decisions and personalized experiences.”

from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

print(generator("Artificial Intelligence will", max_length=30))
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'Artificial Intelligence will also give us a huge opportunity to develop the next great computing platform," said Stephen Hawking, the Chief Scientist at Facebook.\n\nIn a statement, the company said it will continue to build out its AI research and development center, with the goal of "building a platform that is the foundation of future computing applications".\n\n"We are confident that we will be able to deliver the hardware and software that will improve and improve the most efficient computing platform on the planet," it said.'}]

# %%
# Scenario: Game Storyline Generator
# You’re designing a fantasy role‑playing game and need quick ideas for quests and dialogue.
# - The developer types a prompt:
# “The hero enters the ancient forest and discovers…”
# - The GPT‑2 pipeline continues the story:
# “The hero enters the ancient forest and discovers a hidden village where the people whisper of
#  a cursed artifact buried beneath the old ruins.”


# Import library
from transformers import pipeline

# Load GPT-2 model
story_generator = pipeline("text-generation", model="gpt2")

# Prompt for story
prompt = "The hero enters the ancient forest and discovers"

# Generate story
result = story_generator(prompt, max_length=60)

# Print generated story
print(result[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=60) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# The hero enters the ancient forest and discovers a hidden treasure, with the result that a large number of people are dead, and the king has been betrayed by the monster. He orders the heroes to send a guard to the town where they can find the treasure. However, after a few days, the guards are able to find the treasure. The hero's name is Amarnath, a young man from the ancient forest. He has no choice but to lead the villagers into a trap that will destroy the kingdom.
#
# There are many other great books and movies by the author and his books are not only very good, but also very well written. He has been known to show his works on television and he has also been known to speak to hundreds of people.
#
# He has also been known as the author of many books that have been translated into English, and many other books that have been translated into Norwegian, Chinese, French and German.
#
# The book on Amarnath has been given to the people of the village of Sarvak as an opportunity for them to learn more about the village.
#
# In the story, Amarnath has been sent to get revenge for his father's death on the day after his daughter was born. He then decides to return to the village and will kill

# %%
# Scenario: Research Assistant for Academic Papers
# Imagine you’re building a tool for university researchers who analyze large collections of academic papers.
# - A researcher uploads a sentence:
# “Deep learning models are powerful”
# - Your system uses the BERT tokenizer to break the sentence into smaller units (tokens).

from transformers import pipeline
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

text = "Deep learning models are powerful"

tokens = tokenizer.tokenize(text)

print(tokens)
# Out:
# ['deep', 'learning', 'models', 'are', 'powerful']

# %%
# 🏥 Scenario: Healthcare Chatbot for Patient Queries
# A hospital is developing a chatbot to help patients ask questions about their health.
# - A patient types:
# “Deep learning models are powerful” (or in practice, something like “I have chest pain and shortness of breath”).
# - The chatbot uses the BERT tokenizer to break the sentence into tokens:

from transformers import pipeline

# Import tokenizer
from transformers import BertTokenizer

# Load BERT tokenizer
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")

# Patient query
text = "I have chest pain and shortness of breath"

# Tokenize sentence
tokens = tokenizer.tokenize(text)

# Print tokens
print(tokens)
# Out:
# ['i', 'have', 'chest', 'pain', 'and', 'short', '##ness', 'of', 'breath']

# %%
# Scenario: Exploring Creativity in AI Writing
# A university professor is running a workshop on creative writing with AI.
# - The professor gives students the prompt:
# “The future of Artificial Intelligence”
# - The system uses GPT‑2 to generate continuations of the sentence.
# To demonstrate how temperature affects creativity:
# - With temperature = 0.2 (low randomness), the output is more predictable and conservative, e.g.:
# “The future of Artificial Intelligence will bring advancements in healthcare, education, and business.”

from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

prompt = "The future of Artificial Intelligence"

print(generator(prompt, max_length=40, temperature=0.2))
print(generator(prompt, max_length=40, temperature=0.8))
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Passing `generation_config` together with generation-related arguments=({'temperature', 'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'The future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands'}]
# [{'generated_text': "The future of Artificial Intelligence is looking bright.\n\nBut there's a problem. I'll never understand what the future hold for AI. It's impossible to make an argument for or against it, but when people make a good argument in the 21st century, it won't help anybody.\n\nThe reality of AI is that most of us can only imagine the future. But in the 20th century, the human brain evolved into a kind of machine.\n\nSo we need to rethink how we think about machines. To do so, we need to recognize that it's no longer possible.\n\nAn AI is something that comes into being over time. It's a complex machine, a collection of neural networks that make up our world. At the same time, it represents a set of actions we take based on our preferences: how we go about a task, how we interact with objects, what we're thinking, and so on. It is a more accurate description of what we can do next.\n\nAt the same time, when we talk about software, we're not talking about a computer. The way we think about software is that it's a set of rules about what we can do, and we make choices about what those decisions must be based on.\n\nIt"}]

# %%
#  Scenario: Scriptwriting Assistant for Film Production
# A film studio is experimenting with AI to help writers brainstorm dialogue and plot ideas.
# - The writer provides the prompt:
# “The future of Artificial Intelligence”
# - The system generates two versions of the continuation:
# - Temperature = 0.2 (low randomness)
# Output is more predictable and formal, e.g.:
# “The future of Artificial Intelligence will improve industries, enhance productivity, and reshape education.”
# → This is useful for serious, factual narration in a documentary script.
# - Temperature = 0.8 (higher randomness)
# Output is more imaginative and varied, e.g.:
# “The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.”
# → This is perfect for creative dialogue or speculative sci‑fi storytelling


# Import pipeline
from transformers import pipeline

# Load GPT-2 model
generator = pipeline("text-generation", model="gpt2")

# Writer prompt
prompt = "The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn."

# Low randomness (Temperature = 0.2)
output_low = generator(prompt, max_length=40, temperature=0.2)

# High randomness (Temperature = 0.8)
output_high = generator(prompt, max_length=40, temperature=0.8)

# Print results
print("Temperature = 0.2 Output:")
print(output_low[0]["generated_text"])

print("\nTemperature = 0.8 Output:")
print(output_high[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Temperature = 0.2 Output:
# The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.
#
# The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.
#
# The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.
#
# The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.
#
# The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.
#
# The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.
#
# The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.
#
# The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.
#
# The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.
#
# The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.
#
# The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.
#
# The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.
#
# The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.
#
# The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming
#
# Temperature = 0.8 Output:
# The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.
#
# In the new book, Professor John Kessel, an expert and philosopher at the University of Edinburgh and Professor of Philosophy at the University of California at Berkeley, explores the role of consciousness in social and technological history. The book has been translated into several languages, starting with English now.
#
# Professor Kessel, who is the founder and chief executive officer of Google, is particularly interested in 'the Future of Artificial Intelligence,' arguing that the idea of Artificial Intelligence is a myth and that the future is on the one hand a dystopian future, and on the other hand, there is no such thing as 'the future'.
#
# "We have a long way to go, for we need to be able to predict all the technology," he says.
#
# On the one hand, scientists need to be able to make predictions about all the new things that are happening in the future, but if they can't be confident that all of these things will ever happen, then all of them can.
#
# On the other hand, when someone tries to predict what will happen in the next 50 years, they're usually not going to get it. When they try to predict the future, they're going to get it either way.
#
# This gives us the chance to start

# %%
# Scenario: AI‑Powered News Headline Generator
# A digital media company wants to help journalists brainstorm headlines and opening lines for articles.
# - The system asks the journalist to enter a prompt (e.g., “Enter a prompt: The future of Artificial Intelligence”).
# - The GPT‑2 model then generates a continuation of the text, up to 50 tokens.
# - Example output:
# “The future of Artificial Intelligence will reshape industries, redefine creativity, and challenge
#  our understanding of human potential.”

from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

prompt = input("Enter a prompt: ")

output = generator(prompt, max_length=50)

print(output[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Enter a prompt: The future of Artificial Intelligence will reshape industries, redefine creativity, and challenge our understanding of human potential.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# The future of Artificial Intelligence will reshape industries, redefine creativity, and challenge our understanding of human potential. We need to understand what makes us human, and how to help them get there.
#
# In the next few days, learn more about our future of AI by attending our Global AI Summit this weekend.
#
# How does all this work?
#
# The AI project is funded by the UK's Department of Science, Technology and Innovation, and is led by the Cambridge Institute for Advanced Study and the University of Cambridge.
#
# The UK government is the first country to fund the project, but the other major UK government is being funded by the University of Exeter, the University of Nottingham, the Department of Education, the European Commission and the UK Office of Science and Technology Policy.
#
# The project is funded by the Royal Society and is funded by the National Science Foundation.
#
# The UK government's Science and Technology Policy is supported by a £2.5 billion funding package.
#
# How much is this?
#
# The total of $3.6 billion will be spent on the project.
#
# What is the funding?
#
# The amount will be distributed among 10 research universities and 12 research institutions in the UK: the University of Exeter, the University of Reading, the University of Bristol, the University of Cambridge and the University of Leeds.

# %%
# 🎓 Scenario: Student Brainstorming Tool for Essay Writing
# A college student is struggling to start their essay.
# - The system prompts them:
# “Enter a prompt:”
# - The student types:
# “The impact of technology on education”
# - The GPT‑2 model generates a continuation up to 50 tokens, for example:
# “The impact of technology on education has transformed classrooms, enabling online learning,
# personalized study plans, and global collaboration among students.”

# Import pipeline
from transformers import pipeline

# Load GPT-2 model
generator = pipeline("text-generation", model="gpt2")

# Ask student to enter prompt
prompt = input("Enter a prompt: ")

# Generate essay continuation (50 tokens)
result = generator(prompt, max_length=50)

# Print generated text
print("\nGenerated Essay Idea:")
print(result[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Enter a prompt: The impact of technology on education
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generated Essay Idea:
# The impact of technology on education and employment is clear, and the country faces a crisis of trust, lack of direction and even more uncertainty.
#
# The government is also trying to ease tensions with the public sector, which has been criticised for its lack of transparency on its funding.
#
# The government is also trying to bring back a law that aims to stop the government from taking any action against foreign companies that exploit public funds or profit from them.
#
# However, the government is in the midst of building a new business model to attract investment and to boost the economic growth of its states and territories.
#
# The government is also trying to introduce a new law to protect the rights of children to work, which will see the development of a new right for women to earn their own living.
#
# It is also working on a new law for women to have a higher standard of living.
#
# The United Nations Human Rights Committee (HRRC) welcomed the developments and said it was "profoundly concerned" by the lack of progress in promoting access to education.
#
# "The United Nations Human Rights Committee expresses deep concern over the failure of the government to meet its commitments to address the fundamental human rights of children and girls in a fair and equitable way," the committee said.

# %%
# Scenario: AI Model Evaluation in a Startup
# A startup is building an AI‑powered content assistant to help marketers draft product descriptions.
# - The team wants to compare two models: GPT‑2 (larger, more expressive) and DistilGPT‑2 (smaller, faster, distilled version).
# - They use the same prompt:
# “Artificial Intelligence will transform”
# - The system generates two outputs:
# - GPT‑2 Output
# Longer, more detailed continuation, e.g.:
# “Artificial Intelligence will transform industries by automating processes, enhancing creativity, and
# reshaping how humans interact with technology.”
# → Richer but slower to run.
# - DistilGPT‑2 Output


from transformers import pipeline

gpt2 = pipeline("text-generation", model="gpt2")
distilgpt2 = pipeline("text-generation", model="distilgpt2")

prompt = "Artificial Intelligence will transform"

print("GPT2:", gpt2(prompt, max_length=40))
print("DistilGPT2:", distilgpt2(prompt, max_length=40))
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: distilgpt2
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# transformer.h.{0, 1, 2, 3, 4, 5}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# GPT2: [{'generated_text': "Artificial Intelligence will transform every aspect of the human consciousness.\n\nI'm sure many of you are familiar with the concept of AI. But I'm not. I'm not a bot. I'm not a smart guy. I'm not a computer. And I'm not going to be able to solve any of them. In fact, I'm going to be able to find solutions to problems that I'm not even aware of.\n\nI'm also not going to be able to figure out any of the mysteries of how we could make the world a better place.\n\nI'm not going to be able to figure out any of the mysteries of how we could make the world a better place.\n\nI'm not going to be able to say anything about where we should go from here or what problems we should address, or what we should do to make the world a better place.\n\nI'm not going to be able to say anything about how we should go from here or what problems we should address, or what we should do to make the world a better place.\n\nI have a lot of ideas and I'm going to have some of them. These are my personal ideas and I'm going to get to them. And you can share them if you like"}]
# DistilGPT2: [{'generated_text': 'Artificial Intelligence will transform our lives and our lives.\n\n\n\n\nI’ve been interested in the question in the past two years as to how this new technology could help us learn more about what makes us smarter or better.\nWe used to think that by thinking of the ways in which humans could create and develop smarter behavior, we found that humans could learn a lot about the habits that humans use. I found that we were right:\nThis kind of thinking was correct. There is no evidence to indicate that humans do not learn about how to do things. This is a good thing. It is a good thing.\nWe could learn about the ways in which humans are able to learn a lot about how to do things.\nIt could be better to improve our ability to learn about the habits that humans use.\nWhat do you think? Have you tried or tried any other kind of new technology? Share your thoughts in the comments section.'}]

# %%
# Scenario: Educational Tool for Classroom Learning
# A high school teacher is introducing students to AI‑powered writing assistants.
# - The teacher wants to show how different models produce different styles of text.
# - They use the same prompt:
# “Artificial Intelligence will transform”
# - The system generates two outputs:
# - GPT‑2 Output
# More elaborate continuation, e.g.:
# “Artificial Intelligence will transform the way societies function, influencing education, healthcare, and the future of human creativity.”
# → Great for showing students how AI can generate rich, detailed ideas.
# - DistilGPT‑2 Output
# Shorter, faster continuation, e.g.:
# “Artificial Intelligence will transform our daily lives.”
# → Useful for demonstrating concise summaries

# Import pipeline
from transformers import pipeline

# Load GPT-2 model
gpt2_generator = pipeline("text-generation", model="gpt2")

# Load DistilGPT-2 model
distilgpt2_generator = pipeline("text-generation", model="distilgpt2")

# Prompt
prompt = "Artificial Intelligence will transform"

# Generate text using GPT-2
output1 = gpt2_generator(prompt, max_length=40)

# Generate text using DistilGPT-2
output2 = distilgpt2_generator(prompt, max_length=40)

# Print outputs
print("GPT-2 Output:")
print(output1[0]["generated_text"])

print("\nDistilGPT-2 Output:")
print(output2[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: distilgpt2
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# transformer.h.{0, 1, 2, 3, 4, 5}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# GPT-2 Output:
# Artificial Intelligence will transform our lives. A lot of people have read my book, and they've been curious about the way we perceive reality. I think that we need to address this question, and I think it's important to recognize that people have different perspectives on the world.
#
# I think there's a misunderstanding of the reality of human life. We view it as a very, very big, big thing: there's no big big deal in the world. But that's not the whole story. We're all connected in some way. We all have different abilities and different needs.
#
# But what are our needs and what do we want to do with our lives?
#
# I think there's so much to take in. People are living their lives in ways that they feel comfortable and comfortable. There's a lot of things that people are choosing to do with their lives, and the things that people choose to do with their lives. A lot of people don't feel comfortable or comfortable doing things. They're unhappy, they feel like they can't do it, and they're angry, they feel like they're not making a good, honest life.
#
# As your book puts it, people are choosing to do things because they feel like they can't do it.
#
#
#
# DistilGPT-2 Output:
# Artificial Intelligence will transform the world from a digital one to a digital one, and we will be able to change that.
