# %%
import requests

API_TOKEN = "hf_token"
MODEL_ID = "meta-llama/Meta-Llama-3-8B-Instruct"

API_URL = "https://router.huggingface.co/v1/chat/completions"

headers = {
    "Authorization": f"Bearer {API_TOKEN}",
    "Content-Type": "application/json"
}

def query_llm(prompt: str):
    payload = {
        "model": MODEL_ID,
        "messages": [
            {"role": "user", "content": prompt}
        ],
        "max_tokens": 200
    }

    response = requests.post(API_URL, headers=headers, json=payload)
    data = response.json()

    if "choices" in data:
        return data["choices"][0]["message"]["content"]
    else:
        return str(data)


def flag_suspicious(transaction):
    return "Suspicious Transaction"


def mark_normal(transaction):
    return "Normal Transaction"


def fraud_agent(transaction: str):
    thought = query_llm(f"Analyze this transaction: {transaction}")
    print("LLM Thought:", thought)

    if "overseas" in transaction.lower() or "multiple deposits" in transaction.lower():
        action = flag_suspicious
    else:
        action = mark_normal

    result = action(transaction)

    final_answer = query_llm(f"Decision: {result}")
    return final_answer


print(fraud_agent("Payment to overseas account"))
# Out:
# LLM Thought: **Transaction Analysis: Payment to Overseas Account**
#
# **Transaction Details:**
#
# * **Transaction Type:** Payment to overseas account
# * **Amount:** $10,000
# * **Currency:** USD (United States Dollar)
# * **Beneficiary:** ABC Company, located in London, UK
# * **Beneficiary Account:** 1234567890, in pounds sterling (£)
# * **Bank Name:** Barclays Bank, London, UK
# * **Bank Address:** 1 Churchill Place, London E14 5HP, UK
# * **SWIFT/BIC:** BARCGB22
#
# **Transaction Analysis:**
#
# 1. **Purpose:** The transaction is a payment to an overseas account for business or commercial purposes.
# 2. **Risk Assessment:** The transaction involves a high-risk country (the UK) and a high-risk payment method (overseas transfer). The risk of money laundering, terrorism financing, or other illicit activities is higher in such transactions.
# 3. **Compliance Requirements:** The transaction
# **Suspicious Transaction Decision**
#
# **Overview:**
# A suspicious transaction is a financial transaction that raises concerns about money laundering, terrorist financing, or other illicit activities. The decision to flag or investigate a suspicious transaction involves analyzing the transaction's characteristics, the parties involved, and the regulatory requirements.
#
# **Decision Factors:**
#
# 1. **Unusual Transaction Patterns:**
# 	* Large or frequent transactions
# 	* Transactions with no clear purpose or explanation
# 	* Transactions involving multiple parties or accounts
# 2. **High-Risk Countries or Regions:**
# 	* Transactions involving countries or regions with a high risk of money laundering or terrorist financing
# 	* Transactions with a connection to a sanctioned country or entity
# 3. **Inconsistencies in Customer Information:**
# 	* Inaccurate or incomplete customer information
# 	* Discrepancies in customer identification documents
# 4. **Lack of Transaction History:**
# 	* New customer with no prior transaction history
# 	* Customer with a short account history

# %%
#  Scenario: The Hospital’s AI Appointment Agent
# Imagine a hospital has deployed an AI-powered agent named MediLLM.
# Its job is to monitor patient appointment requests and decide whether the requested slot is available or needs rescheduling.

# Step 1 — Thinking (Reasoning)
# Whenever a patient request comes in, MediLLM first analyzes the details:
# - Example: “Request for Dr. Sharma at 10 AM tomorrow”
# - MediLLM thinks: “Analyzing appointment request: Dr. Sharma, 10 AM tomorrow.”

# Step 2 — Planning (Choosing an Action)
# Based on the thought, MediLLM decides which tool to use:
# - If the requested slot is free, it plans to confirm appointment.
# - If the slot is already booked, it plans to suggest rescheduling.

# Step 3 — Acting (Running Tools)
# MediLLM hands over the decision to AppointmentTools, which executes the action:
# - confirm_slot → returns “Appointment Confirmed”
# - suggest_reschedule → returns “Slot Unavailable, Please Reschedule”

# Step 4 — Answering (Final Decision)
# Once a clear classification is reached, MediLLM announces the decision:
# - “Decision: Appointment Confirmed”
# - “Decision: Slot Unavailable, Please Reschedule”

import requests

API_TOKEN = "hf_token"
MODEL_ID = "meta-llama/Meta-Llama-3-8B-Instruct"

API_URL = "https://router.huggingface.co/v1/chat/completions"

headers = {
    "Authorization": f"Bearer {API_TOKEN}",
    "Content-Type": "application/json"
}


# LLM Query Function
def query_llm(prompt: str):
    payload = {
        "model": MODEL_ID,
        "messages": [
            {"role": "user", "content": prompt}
        ],
        "max_tokens": 200
    }

    response = requests.post(API_URL, headers=headers, json=payload)
    data = response.json()

    if "choices" in data:
        return data["choices"][0]["message"]["content"]
    else:
        return str(data)


# Tools
def confirm_slot(request):
    return "Appointment Confirmed"

def suggest_reschedule(request):
    return "Slot Unavailable, Please Reschedule"


# Agent
def appointment_agent(request: str):

    # Step 1 — Thinking
    thought = query_llm(f"Analyze this appointment request: {request}")
    print("LLM Thought:", thought)

    # Step 2 — Planning
    if "10 am" in request.lower() or "busy" in request.lower():
        action = suggest_reschedule
    else:
        action = confirm_slot

    # Step 3 — Acting
    result = action(request)

    # Step 4 — Answering
    final_answer = query_llm(f"Decision: {result}")
    return final_answer


# Run
print(appointment_agent("Request for Dr. Sharma at 10 AM tomorrow"))
print(appointment_agent("Request for Dr. Sharma at 2 PM tomorrow"))
# Out:
# LLM Thought: To analyze this appointment request, let's break down the key components:
#
# 1. **Requestee:** Dr. Sharma - This is the person or professional being requested to meet.
# 2. **Time:** 10 AM - This is the specific time when the meeting or appointment is requested to take place.
# 3. **Date:** Tomorrow - The appointment is requested for the next day, which implies that the current day is not specified.
#
# To make this appointment request more effective, consider adding the following details:
#
# - **Date:** Specify the exact date to avoid any confusion.
# - **Location:** Mention the location where the appointment is requested, such as the doctor's office or a specific room.
# - **Duration:** Indicate the expected length of the appointment to ensure both parties are prepared.
# - **Purpose:** Briefly mention the purpose or reason for the appointment to help the doctor prepare.
#
# Here's an example of how the revised appointment request could look:
#
# "Request for Dr. Sharma at 10 AM
# It seems like you're facing an issue where a slot or appointment is unavailable, and you're being asked to reschedule. Here are some possible reasons and suggestions to help you navigate this situation:
#
# 1. **Overbooking**: The service provider might have overbooked themselves, resulting in a slot being unavailable.
# 2. **Last-minute cancellation**: Another appointment might have been cancelled at the last minute, freeing up a slot.
# 3. **Technical issues**: The service provider's scheduling system might be experiencing technical difficulties, causing the slot to be unavailable.
#
# To reschedule:
#
# 1. **Contact the service provider**: Reach out to the service provider directly and ask about available slots. They might be able to accommodate you on a different day or time.
# 2. **Check their website or social media**: Sometimes, service providers update their availability on their website or social media channels.
# 3. **Be flexible**: Be open to different days or times. You might be able to schedule an appointment on a less busy
# LLM Thought: Analysis of the appointment request:
#
# 1. **Recipient**: The request is for Dr. Sharma, implying that the sender wants to schedule an appointment with the doctor.
#
# 2. **Time Slot**: The appointment is requested for 2 PM tomorrow, indicating that the sender is looking for a specific time slot.
#
# 3. **Date**: The date of the appointment is specified as "tomorrow," which is a relative term and may cause ambiguity. A more specific date, such as "July 27, 2024," would be recommended to avoid confusion.
#
# 4. **Lack of specifics**: The request does not include any specific details about the purpose of the appointment or any relevant medical history. This could lead to delays or additional steps in the scheduling process.
#
# 5. **Assumed availability**: The sender assumes that Dr. Sharma will be available at the specified time, which may not be the case. It would be more polite and efficient to confirm Dr. Sharma's availability before sending the request.
#
# To
# It seems like you've received some good news. What's the appointment about, if you don't mind me asking? Was it a job, a medical appointment, or something else entirely?
