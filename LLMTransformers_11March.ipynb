# %% [markdown]
# <a href="https://colab.research.google.com/github/Shabbu123766/Project-Repository/blob/main/LLMTransformers_11March.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata

api_key = userdata.get('my_api_key')

print("API key loaded successfully")
# Out:
# API key loaded successfully

# %%
#  Scenario: AI‑Powered Email Assistant
# You’re building an email drafting assistant for a corporate team.
# - When a user starts typing:
# “Artificial Intelligence will…”
# - The assistant uses GPT‑2 to auto‑complete the sentence with a coherent continuation.
# - Example output:
# “Artificial Intelligence will transform the way businesses interact with customers,
# enabling faster decisions and personalized experiences.”

from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

print(generator("Artificial Intelligence will", max_length=30))
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Passing `generation_config` together with generation-related arguments=({'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': "Artificial Intelligence will be a big part of the future of the digital world. We can now understand how to build AI that will be able to do what we did with machine intelligence and why.\n\nA machine learning system is a system that learns to change its behavior with a set of parameters. A machine learning system learns to change its behavior in order to adapt to new conditions. We've seen that in a variety of different industries, including robotics, medicine, transportation, and the Internet of Things.\n\nAI is a big part of the future of the digital world. We can now understand how to build AI that will be able to do what we did with machine intelligence and why.\n\nBut I want to emphasize just how important AI is in the future. And there are a lot of ways that artificial intelligence can come in handy for this.\n\nAI programs for learning a lot of information. They can help you learn a lot of information. You can learn a lot of information about a person, about a business, about a family, about a car. They can help you learn a lot about a city, about a place, about a person, about a person in a city.\n\nAI programs for learning a lot of information. They can help you learn a lot"}]

# %%
# Scenario: Game Storyline Generator
# You’re designing a fantasy role‑playing game and need quick ideas for quests and dialogue.
# - The developer types a prompt:
# “The hero enters the ancient forest and discovers…”
# - The GPT‑2 pipeline continues the story:
# “The hero enters the ancient forest and discovers a hidden village where the people whisper of
#  a cursed artifact buried beneath the old ruins.”


# Import library
from transformers import pipeline

# Load GPT-2 model
story_generator = pipeline("text-generation", model="gpt2")

# Prompt for story
prompt = "The hero enters the ancient forest and discovers"

# Generate story
result = story_generator(prompt, max_length=60)

# Print generated story
print(result[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=60) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# The hero enters the ancient forest and discovers that a mysterious spirit is stirring the forest. He uses his powers to stop the spirit from spreading through the air, then proceeds to remove him and place him in a new dimension.
#
# When the spirit of the forest is destroyed, the Hero is saved from the demon, who is seeking revenge on all those who have been hurt. The Hero then begins to transform into a human, but it is not until he returns to the hero's world that he realizes that the spirit of the forest is indeed not his, and that the Hero does not know that its existence is actually a lie. The hero then makes his way to the Spirit World by using his powers to help the Hero and find the spirit of the forest. However, the Hero only knows that the spirit of the forest is the Hero, and that he cannot help it by killing it.
#
# In the end, the Hero is saved from the demon by using the power of his powers to re-create himself from the ashes, and the Hero realizes that the spirit of the forest is actually the Hero, and that his power is not his at all. The Hero then transforms into a human, but it is not until he finally breaks free of his own body that the Hero realizes that he is actually the Hero,

# %%
# Scenario: Research Assistant for Academic Papers
# Imagine you’re building a tool for university researchers who analyze large collections of academic papers.
# - A researcher uploads a sentence:
# “Deep learning models are powerful”
# - Your system uses the BERT tokenizer to break the sentence into smaller units (tokens).

from transformers import pipeline
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

text = "Deep learning models are powerful"

tokens = tokenizer.tokenize(text)

print(tokens)
# Out:
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# ['deep', 'learning', 'models', 'are', 'powerful']

# %%
# 🏥 Scenario: Healthcare Chatbot for Patient Queries
# A hospital is developing a chatbot to help patients ask questions about their health.
# - A patient types:
# “Deep learning models are powerful” (or in practice, something like “I have chest pain and shortness of breath”).
# - The chatbot uses the BERT tokenizer to break the sentence into tokens:

from transformers import pipeline

# Import tokenizer
from transformers import BertTokenizer

# Load BERT tokenizer
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")

# Patient query
text = "I have chest pain and shortness of breath"

# Tokenize sentence
tokens = tokenizer.tokenize(text)

# Print tokens
print(tokens)
# Out:
# ['i', 'have', 'chest', 'pain', 'and', 'short', '##ness', 'of', 'breath']

# %%
# Scenario: Exploring Creativity in AI Writing
# A university professor is running a workshop on creative writing with AI.
# - The professor gives students the prompt:
# “The future of Artificial Intelligence”
# - The system uses GPT‑2 to generate continuations of the sentence.
# To demonstrate how temperature affects creativity:
# - With temperature = 0.2 (low randomness), the output is more predictable and conservative, e.g.:
# “The future of Artificial Intelligence will bring advancements in healthcare, education, and business.”

from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

prompt = "The future of Artificial Intelligence"

print(generator(prompt, max_length=40, temperature=0.2))
print(generator(prompt, max_length=40, temperature=0.8))
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Passing `generation_config` together with generation-related arguments=({'max_length', 'temperature'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'The future of Artificial Intelligence is not yet clear. But if we are to have a truly intelligent society, we need to understand the nature of the human mind.\n\nThe Future of Artificial Intelligence\n\nThe future of artificial intelligence is not yet clear. But if we are to have a truly intelligent society, we need to understand the nature of the human mind.\n\nThe future of artificial intelligence is not yet clear. But if we are to have a truly intelligent society, we need to understand the nature of the human mind.\n\nThe future of artificial intelligence is not yet clear. But if we are to have a truly intelligent society, we need to understand the nature of the human mind.\n\nThe future of artificial intelligence is not yet clear. But if we are to have a truly intelligent society, we need to understand the nature of the human mind.\n\nThe future of artificial intelligence is not yet clear. But if we are to have a truly intelligent society, we need to understand the nature of the human mind.\n\nThe future of artificial intelligence is not yet clear. But if we are to have a truly intelligent society, we need to understand the nature of the human mind.\n\nThe future of artificial intelligence is not yet clear. But if we are to have'}]
# [{'generated_text': 'The future of Artificial Intelligence – and human culture – is uncertain because of the uncertainty of the current status of the technology. According to Professor Jens Keller, "There is no clear, reliable, universal consensus about whether certain processes are able to live on such a level that they will be completely automated. But if we can make certain machines able to live on the level of self-organising, self-evident self-organisation that they have at the level of real humans, then they will become completely self-organising, self-evident."\n\nDr. Jens Keller says this is because of the lack of information available to scientists on the topic. "It is very difficult to know what the human brain is capable of in terms of how it is programmed, how it interacts with its environment, how it interacts with its environment in ways that are not actually understood. But this is not a question that can be solved with a single system theory or a system of natural language instruction. It is a question of understanding the human-machine relationship through one system. There has been a long debate about how to deal with this. For example, a question that has been often asked is "what do I understand as human, what is the human brain to do?" It has now become clear'}]

# %%
#  Scenario: Scriptwriting Assistant for Film Production
# A film studio is experimenting with AI to help writers brainstorm dialogue and plot ideas.
# - The writer provides the prompt:
# “The future of Artificial Intelligence”
# - The system generates two versions of the continuation:
# - Temperature = 0.2 (low randomness)
# Output is more predictable and formal, e.g.:
# “The future of Artificial Intelligence will improve industries, enhance productivity, and reshape education.”
# → This is useful for serious, factual narration in a documentary script.
# - Temperature = 0.8 (higher randomness)
# Output is more imaginative and varied, e.g.:
# “The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.”
# → This is perfect for creative dialogue or speculative sci‑fi storytelling


# Import pipeline
from transformers import pipeline

# Load GPT-2 model
generator = pipeline("text-generation", model="gpt2")

# Writer prompt
prompt = "The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn."

# Low randomness (Temperature = 0.2)
output_low = generator(prompt, max_length=40, temperature=0.2)

# High randomness (Temperature = 0.8)
output_high = generator(prompt, max_length=40, temperature=0.8)

# Print results
print("Temperature = 0.2 Output:")
print(output_low[0]["generated_text"])

print("\nTemperature = 0.8 Output:")
print(output_high[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Temperature = 0.2 Output:
# The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.
#
# The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.
#
# The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.
#
# The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.
#
# The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.
#
# The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.
#
# The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.
#
# The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.
#
# The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.
#
# The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.
#
# The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.
#
# The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.
#
# The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.
#
# The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming
#
# Temperature = 0.8 Output:
# The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn. The story of artificial intelligence is an essential part of the future of AI.
#
# A. Artificial Intelligence has been through a lot and a lot of work, but once I'm finished writing this book, I'd like to give it another shot.
#
# What can you tell us about Artificial Intelligence and how it will affect your life?
#
# A. The book is set in a dystopian future in which artificial intelligence is poised to destroy humanity. We'll be watching the development of artificial intelligence, but the future will never be fully understood. However, we can expect more to come from artificial intelligence if we can trust our current knowledge.
#
# A. The first thing I'll tell you is that an AI has tremendous potential. It will fundamentally change our world, and even the world of science fiction. I think that this book will be the most influential book by any writer to date, and I can't promise it won't be so. I'm hoping that it will be of interest to readers of science fiction, philosophy, and philosophy of science fiction. I'm certainly hoping that this book will make a contribution to the field of Artificial Intelligence.
#
# In addition to this book, the Book of the Prophecies will also include a book that will be a meditation on

# %%
# Scenario: AI‑Powered News Headline Generator
# A digital media company wants to help journalists brainstorm headlines and opening lines for articles.
# - The system asks the journalist to enter a prompt (e.g., “Enter a prompt: The future of Artificial Intelligence”).
# - The GPT‑2 model then generates a continuation of the text, up to 50 tokens.
# - Example output:
# “The future of Artificial Intelligence will reshape industries, redefine creativity, and challenge
#  our understanding of human potential.”

from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

prompt = input("Enter a prompt: ")

output = generator(prompt, max_length=50)

print(output[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Enter a prompt: The future of Artificial Intelligence will reshape industries, redefine creativity, and challenge our understanding of human potential.”
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# The future of Artificial Intelligence will reshape industries, redefine creativity, and challenge our understanding of human potential.”
#
# Read More

# %%
# 🎓 Scenario: Student Brainstorming Tool for Essay Writing
# A college student is struggling to start their essay.
# - The system prompts them:
# “Enter a prompt:”
# - The student types:
# “The impact of technology on education”
# - The GPT‑2 model generates a continuation up to 50 tokens, for example:
# “The impact of technology on education has transformed classrooms, enabling online learning,
# personalized study plans, and global collaboration among students.”

# Import pipeline
from transformers import pipeline

# Load GPT-2 model
generator = pipeline("text-generation", model="gpt2")

# Ask student to enter prompt
prompt = input("Enter a prompt: ")

# Generate essay continuation (50 tokens)
result = generator(prompt, max_length=50)

# Print generated text
print("\nGenerated Essay Idea:")
print(result[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Enter a prompt: The impact of technology on education
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generated Essay Idea:
# The impact of technology on education and social care can be found in the following sections.
#
# The effects of technology on human rights
#
# 1. The impacts of technology on human rights, including the right to education and social care, on the rights of minors in their environment, mental health and other relevant rights
#
# 2. The impacts of technology in schools and on the educational system
#
# 3. The impacts of technology on the rights of children with disabilities in their environment
#
# 4. The impacts of technology in schools and on the educational system
#
# 5. The impacts of technology in schools and on the educational system
#
# 6. The impacts of technology in schools and on the educational system
#
# 7. The impacts of technology in schools and on the educational system
#
# 8. The impacts of technology in schools and on the educational system
#
# 9. The impacts of technology in schools and on the educational system
#
# 10. The impacts of technology in schools and on the educational system
#
# 11. The impacts of technology in schools and on the educational system
#
# 12. The impacts of technology in schools and on the educational system
#
# 13. The impacts of technology in schools and on the educational system
#
# 14. The impacts of technology in schools and on the educational system

# %%
# Scenario: AI Model Evaluation in a Startup
# A startup is building an AI‑powered content assistant to help marketers draft product descriptions.
# - The team wants to compare two models: GPT‑2 (larger, more expressive) and DistilGPT‑2 (smaller, faster, distilled version).
# - They use the same prompt:
# “Artificial Intelligence will transform”
# - The system generates two outputs:
# - GPT‑2 Output
# Longer, more detailed continuation, e.g.:
# “Artificial Intelligence will transform industries by automating processes, enhancing creativity, and
# reshaping how humans interact with technology.”
# → Richer but slower to run.
# - DistilGPT‑2 Output


from transformers import pipeline

gpt2 = pipeline("text-generation", model="gpt2")
distilgpt2 = pipeline("text-generation", model="distilgpt2")

prompt = "Artificial Intelligence will transform"

print("GPT2:", gpt2(prompt, max_length=40))
print("DistilGPT2:", distilgpt2(prompt, max_length=40))
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: distilgpt2
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# transformer.h.{0, 1, 2, 3, 4, 5}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# GPT2: [{'generated_text': "Artificial Intelligence will transform our lives and our cities in ways that will reduce our dependence on coal, increase energy efficiency and reduce our reliance on other fuels. We are taking a step forward.\n\nIn November, we introduced the Artificial Intelligence (AI) Framework that will help businesses and governments build and maintain an AI-powered economy to meet the growing needs of our business leaders.\n\nAI is an essential tool for leaders and organizations to build the capacity to meet the growing needs of their employees. It allows them to create and manage AI that can be used to build systems that are easily adaptable to the needs of their organizations and to improve the way they make decisions for their employees.\n\nThe AI Framework will enable companies to build AI for their employees, and to build AI that is in alignment with the needs of their employees.\n\nWhile AI's strengths and weaknesses can be explained away with hindsight, the following are some of the ways that AI will be adapted to meet the specific needs of its employees\n\nEfficiency\n\nIn order to meet the needs of its employees, AI will be able to perform many tasks within the constraints of its current technology.\n\nFor example, it can perform tasks that are not human-related, such as maintaining business customer data and keeping track of"}]
# DistilGPT2: [{'generated_text': 'Artificial Intelligence will transform the world and our lives.\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n'}]

# %%
# Scenario: Educational Tool for Classroom Learning
# A high school teacher is introducing students to AI‑powered writing assistants.
# - The teacher wants to show how different models produce different styles of text.
# - They use the same prompt:
# “Artificial Intelligence will transform”
# - The system generates two outputs:
# - GPT‑2 Output
# More elaborate continuation, e.g.:
# “Artificial Intelligence will transform the way societies function, influencing education, healthcare, and the future of human creativity.”
# → Great for showing students how AI can generate rich, detailed ideas.
# - DistilGPT‑2 Output
# Shorter, faster continuation, e.g.:
# “Artificial Intelligence will transform our daily lives.”
# → Useful for demonstrating concise summaries

# Import pipeline
from transformers import pipeline

# Load GPT-2 model
gpt2_generator = pipeline("text-generation", model="gpt2")

# Load DistilGPT-2 model
distilgpt2_generator = pipeline("text-generation", model="distilgpt2")

# Prompt
prompt = "Artificial Intelligence will transform"

# Generate text using GPT-2
output1 = gpt2_generator(prompt, max_length=40)

# Generate text using DistilGPT-2
output2 = distilgpt2_generator(prompt, max_length=40)

# Print outputs
print("GPT-2 Output:")
print(output1[0]["generated_text"])

print("\nDistilGPT-2 Output:")
print(output2[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: distilgpt2
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# transformer.h.{0, 1, 2, 3, 4, 5}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# GPT-2 Output:
# Artificial Intelligence will transform the world of data processing in a transformative way, enabling the human mind to be the most efficient human tool in the world.
#
# "The future will be driven by the creative ability of our AI," said Alexey Buryakov, the head of the AI division at IBM. "Our AI will be the ultimate resource in the field."
#
# The AI breakthrough will be the largest and most significant development in the history of AI. It will be "the most significant development in the history of AI," said Buryakov.
#
# The AI breakthrough will be the largest and most significant development in the history of AI. It will be the most significant development in the history of AI. It will be the most significant development in the history of AI. It will be the most significant development in the history of AI. It will be the most significant development in the history of AI. It will be the most significant development in the history of AI. It will be the most significant development in the history of AI. It will be the most significant development in the history of AI. It will be the most significant development in the history of AI. It will be the most significant development in the history of AI. It will be the most significant development in the history of AI.
#
# DistilGPT-2 Output:
# Artificial Intelligence will transform a lot of people's lives to a virtual reality. It's a new technology that will dramatically change the lives of people who don't need to be in a virtual reality field. It'll transform our lives, our lives, our lives, our lives, our lives. The technology and its promise will make people more comfortable with their lives, and better able to communicate with their loved ones.
