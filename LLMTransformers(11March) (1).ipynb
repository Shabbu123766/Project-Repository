# %%
#  Scenario: AI‑Powered Email Assistant
# You’re building an email drafting assistant for a corporate team.
# - When a user starts typing:
# “Artificial Intelligence will…”
# - The assistant uses GPT‑2 to auto‑complete the sentence with a coherent continuation.
# - Example output:
# “Artificial Intelligence will transform the way businesses interact with customers,
# enabling faster decisions and personalized experiences.”

from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

print(generator("Artificial Intelligence will", max_length=30))
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'Artificial Intelligence will continue to evolve, and the ability to create and use AI technology will continue to evolve. At the same time, we need to see the full range of different applications of Artificial Intelligence."\n\nThe technology, which is being developed by the University of Warwick, is expected to be used to build artificial intelligence tools such as a vision system, to assist in human-controlled car driving, or to help solve health problems such as heart disease.\n\nIt will also enable AI to be used in the field of robotics, and to build artificial weapons that are able to detect and kill people.'}]

# %%
# Scenario: Game Storyline Generator
# You’re designing a fantasy role‑playing game and need quick ideas for quests and dialogue.
# - The developer types a prompt:
# “The hero enters the ancient forest and discovers…”
# - The GPT‑2 pipeline continues the story:
# “The hero enters the ancient forest and discovers a hidden village where the people whisper of
#  a cursed artifact buried beneath the old ruins.”


# Import library
from transformers import pipeline

# Load GPT-2 model
story_generator = pipeline("text-generation", model="gpt2")

# Prompt for story
prompt = "The hero enters the ancient forest and discovers"

# Generate story
result = story_generator(prompt, max_length=60)

# Print generated story
print(result[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=60) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# The hero enters the ancient forest and discovers the Dragon, and he makes his first appearance in the "Wizard of the Southern Forest" storyline.
#
# The hero is the main antagonist, and the story begins with the heroes in the jungle. The first scene of the story is where the heroes meet the dragon. The hero is a warrior named Jiro, and his name is "Lan" who is known as the Dragon. The Dragon is described as a fearsome and powerful being, a beast that can control the earth and the sky. The hero is defeated by Lain and he becomes the first hero known to have defeated the dragon. After this, Lain defeats his rival, and the hero is made a member of the Dragon Society.
#
# In the Dragon Society, the heroes can be found participating in various competitions and fights. In the first scene of the story, the Dragon Society is founded, with a number of members. In the second scene, the Dragon Society begins to disband and the heroes are all gone.
#
# The hero becomes the first hero to become a member of the Dragon Society. The hero can also become a member of the Dragon Society by giving a dragon's name or by giving the Dragon's name to a person who is a member of the Dragon Society.
#
# During the

# %%
# Scenario: Research Assistant for Academic Papers
# Imagine you’re building a tool for university researchers who analyze large collections of academic papers.
# - A researcher uploads a sentence:
# “Deep learning models are powerful”
# - Your system uses the BERT tokenizer to break the sentence into smaller units (tokens).

from transformers import pipeline
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

text = "Deep learning models are powerful"

tokens = tokenizer.tokenize(text)

print(tokens)
# Out:
# ['deep', 'learning', 'models', 'are', 'powerful']

# %%
# 🏥 Scenario: Healthcare Chatbot for Patient Queries
# A hospital is developing a chatbot to help patients ask questions about their health.
# - A patient types:
# “Deep learning models are powerful” (or in practice, something like “I have chest pain and shortness of breath”).
# - The chatbot uses the BERT tokenizer to break the sentence into tokens:

from transformers import pipeline

# Import tokenizer
from transformers import BertTokenizer

# Load BERT tokenizer
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")

# Patient query
text = "I have chest pain and shortness of breath"

# Tokenize sentence
tokens = tokenizer.tokenize(text)

# Print tokens
print(tokens)
# Out:
# ['i', 'have', 'chest', 'pain', 'and', 'short', '##ness', 'of', 'breath']

# %%
# Scenario: Exploring Creativity in AI Writing
# A university professor is running a workshop on creative writing with AI.
# - The professor gives students the prompt:
# “The future of Artificial Intelligence”
# - The system uses GPT‑2 to generate continuations of the sentence.
# To demonstrate how temperature affects creativity:
# - With temperature = 0.2 (low randomness), the output is more predictable and conservative, e.g.:
# “The future of Artificial Intelligence will bring advancements in healthcare, education, and business.”

from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

prompt = "The future of Artificial Intelligence"

print(generator(prompt, max_length=40, temperature=0.2))
print(generator(prompt, max_length=40, temperature=0.8))
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Passing `generation_config` together with generation-related arguments=({'max_length', 'temperature'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'The future of Artificial Intelligence is in the hands of the next generation of AI researchers.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI researchers.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI researchers.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI researchers.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI researchers.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI researchers.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI researchers.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI researchers.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI researchers.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI researchers.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI researchers.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI researchers.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI researchers.\n\nThe future of Artificial Intelligence is in the hands of the next generation of'}]
# [{'generated_text': 'The future of Artificial Intelligence and Computer Science.\n\nA key role for AI is to help shape and develop new technologies with unprecedented efficiency and effectiveness, with all the same security and quality guarantees. Our goal is to bring AI to the forefront of all areas of innovation—from business development to healthcare, from the field of robotics to medical robotics—with a focus on providing the best possible product.\n\nAs a university, we offer a number of graduate and undergraduate courses and provide the best of both worlds. We provide comprehensive information online, and are available for student and faculty research and teaching. It is very useful for students to find out if our faculty or students are already working in the field of AI. We also offer our courses on advanced computing, machine intelligence, etc., as well as graduate and undergraduate degrees in Computer Science, Mathematics, and Artificial Intelligence.\n\nAbout the University of Toronto\n\nThe University of Toronto is a major research and business university where students, faculty and staff are working together to bring an end to the human-dominated culture of technology and human-centric thought. The University has a dedicated team of highly qualified leaders who are passionate about advancing and building a truly world-class student experience.'}]

# %%
#  Scenario: Scriptwriting Assistant for Film Production
# A film studio is experimenting with AI to help writers brainstorm dialogue and plot ideas.
# - The writer provides the prompt:
# “The future of Artificial Intelligence”
# - The system generates two versions of the continuation:
# - Temperature = 0.2 (low randomness)
# Output is more predictable and formal, e.g.:
# “The future of Artificial Intelligence will improve industries, enhance productivity, and reshape education.”
# → This is useful for serious, factual narration in a documentary script.
# - Temperature = 0.8 (higher randomness)
# Output is more imaginative and varied, e.g.:
# “The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.”
# → This is perfect for creative dialogue or speculative sci‑fi storytelling


# Import pipeline
from transformers import pipeline

# Load GPT-2 model
generator = pipeline("text-generation", model="gpt2")

# Writer prompt
prompt = "The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn."

# Low randomness (Temperature = 0.2)
output_low = generator(prompt, max_length=40, temperature=0.2)

# High randomness (Temperature = 0.8)
output_high = generator(prompt, max_length=40, temperature=0.8)

# Print results
print("Temperature = 0.2 Output:")
print(output_low[0]["generated_text"])

print("\nTemperature = 0.8 Output:")
print(output_high[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Temperature = 0.2 Output:
# The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.
#
# The Future of Artificial Intelligence
#
# The future of artificial intelligence is uncertain.
#
# The Future of Artificial Intelligence
#
# The future of artificial intelligence is uncertain.
#
# The Future of Artificial Intelligence
#
# The future of artificial intelligence is uncertain.
#
# The Future of Artificial Intelligence
#
# The future of artificial intelligence is uncertain.
#
# The Future of Artificial Intelligence
#
# The future of artificial intelligence is uncertain.
#
# The Future of Artificial Intelligence
#
# The future of artificial intelligence is uncertain.
#
# The Future of Artificial Intelligence
#
# The future of artificial intelligence is uncertain.
#
# The Future of Artificial Intelligence
#
# The future of artificial intelligence is uncertain.
#
# The Future of Artificial Intelligence
#
# The future of artificial intelligence is uncertain.
#
# The Future of Artificial Intelligence
#
# The future of artificial intelligence is uncertain.
#
# The Future of Artificial Intelligence
#
# The future of artificial intelligence is uncertain.
#
# The Future of Artificial Intelligence
#
# The future of artificial intelligence is uncertain.
#
# The Future of Artificial Intelligence
#
# The future of artificial intelligence is uncertain.
#
# The Future of Artificial Intelligence
#
# The future of artificial intelligence is uncertain.
#
# The Future of Artificial Intelligence
#
# The future of artificial intelligence is uncertain.
#
#
# Temperature = 0.8 Output:
# The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.

# %%
# Scenario: AI Model Evaluation in a Startup
# A startup is building an AI‑powered content assistant to help marketers draft product descriptions.
# - The team wants to compare two models: GPT‑2 (larger, more expressive) and DistilGPT‑2 (smaller, faster, distilled version).
# - They use the same prompt:
# “Artificial Intelligence will transform”
# - The system generates two outputs:
# - GPT‑2 Output
# Longer, more detailed continuation, e.g.:
# “Artificial Intelligence will transform industries by automating processes, enhancing creativity, and
# reshaping how humans interact with technology.”
# → Richer but slower to run.
# - DistilGPT‑2 Output


from transformers import pipeline

gpt2 = pipeline("text-generation", model="gpt2")
distilgpt2 = pipeline("text-generation", model="distilgpt2")

prompt = "Artificial Intelligence will transform"

print("GPT2:", gpt2(prompt, max_length=40))
print("DistilGPT2:", distilgpt2(prompt, max_length=40))
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: distilgpt2
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# transformer.h.{0, 1, 2, 3, 4, 5}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# GPT2: [{'generated_text': 'Artificial Intelligence will transform what we do with computers to be much more personal and personal. We will not only reduce the number of people and places we are able to find, but we will also make our lives more convenient.\n\n"We are investing in the technology of artificial intelligence to provide the most effective and cost-effective solutions to ensure that we have the most accurate and cost-effective solutions for our everyday needs for the betterment of the planet," said Dr. Christopher Murray, the Executive Director of IBM Watson.\n\n"We are building a new generation of AI technology that will drive innovation and improve the lives of our users and our businesses."\n\nThe IBM Watson AI platform, developed by the company, will enable the company to provide support to a wide range of customers for a range of applications, including the provision of analytics for real time, information technology, information security and other data services.\n\n"I believe that today\'s developments in artificial intelligence can lead to unprecedented opportunities to improve our lives, and that these innovations are in fact of great application," said Dr. Gregory Luscombe, IBM Watson\'s Director of Global Head of Research.\n\n"We are now at a point where we are able to provide what we call the "smart home" and the home automation'}]
# DistilGPT2: [{'generated_text': 'Artificial Intelligence will transform the way many of us live.\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n'}]

# %%
# Scenario: Educational Tool for Classroom Learning
# A high school teacher is introducing students to AI‑powered writing assistants.
# - The teacher wants to show how different models produce different styles of text.
# - They use the same prompt:
# “Artificial Intelligence will transform”
# - The system generates two outputs:
# - GPT‑2 Output
# More elaborate continuation, e.g.:
# “Artificial Intelligence will transform the way societies function, influencing education, healthcare, and the future of human creativity.”
# → Great for showing students how AI can generate rich, detailed ideas.
# - DistilGPT‑2 Output
# Shorter, faster continuation, e.g.:
# “Artificial Intelligence will transform our daily lives.”
# → Useful for demonstrating concise summaries

# Import pipeline
from transformers import pipeline

# Load GPT-2 model
gpt2_generator = pipeline("text-generation", model="gpt2")

# Load DistilGPT-2 model
distilgpt2_generator = pipeline("text-generation", model="distilgpt2")

# Prompt
prompt = "Artificial Intelligence will transform"

# Generate text using GPT-2
output1 = gpt2_generator(prompt, max_length=40)

# Generate text using DistilGPT-2
output2 = distilgpt2_generator(prompt, max_length=40)

# Print outputs
print("GPT-2 Output:")
print(output1[0]["generated_text"])

print("\nDistilGPT-2 Output:")
print(output2[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: distilgpt2
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# transformer.h.{0, 1, 2, 3, 4, 5}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# GPT-2 Output:
# Artificial Intelligence will transform the world of gaming by transforming the way we think about games and how we think about games. The industry is changing rapidly and with it the ability to help players create, develop, and share experiences."
#
# The company will release the new game to the public for the first time on February 5, 2014.
#
# DistilGPT-2 Output:
# Artificial Intelligence will transform our daily lives into a world of information and data that isn't just about our heads. It will transform our lives into a world of information and data that isn't just about our heads. It will transform our lives into a world of information and data that isn't just about our heads. It will transform our lives into a world of information and data that isn't just about our heads.
