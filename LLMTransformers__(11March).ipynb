# %%
#  Scenario: AI‑Powered Email Assistant
# You’re building an email drafting assistant for a corporate team.
# - When a user starts typing:
# “Artificial Intelligence will…”
# - The assistant uses GPT‑2 to auto‑complete the sentence with a coherent continuation.
# - Example output:
# “Artificial Intelligence will transform the way businesses interact with customers,
# enabling faster decisions and personalized experiences.”

from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

print(generator("Artificial Intelligence will", max_length=30))
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Passing `generation_config` together with generation-related arguments=({'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'Artificial Intelligence will also be able to find and use some of the most advanced human-machine interfaces ever created, and will help solve many of the fundamental problems associated with human-machine interaction today.\n\nThis will also be a huge change over the past 30 years as AI will be able to find and use many of the most advanced human-machine interfaces ever created, and will help solve many of the fundamental problems associated with human-machine interaction today. Artificial Intelligence will also be able to find and use many of the most advanced human-machine interfaces ever created, and will help solve many of the fundamental problems associated with human-machine interaction today.\n\nIn addition to the exciting breakthroughs being made by artificial intelligence, the potential for real-world applications of the AI will continue to grow. There will be a large number of new opportunities for AI to improve our lives and our lives can be enhanced through new technology such as self-driving cars.\n\nThe future of AI\n\nThe AI will be able to solve many of the fundamental problems associated with human-machine interaction today. The future of AI will be a huge change in the way we think about and interact with our human-machine interactions for decades to come.\n\nIt is important to note that these breakthroughs are'}]

# %%
# Scenario: Game Storyline Generator
# You’re designing a fantasy role‑playing game and need quick ideas for quests and dialogue.
# - The developer types a prompt:
# “The hero enters the ancient forest and discovers…”
# - The GPT‑2 pipeline continues the story:
# “The hero enters the ancient forest and discovers a hidden village where the people whisper of
#  a cursed artifact buried beneath the old ruins.”


# Import library
from transformers import pipeline

# Load GPT-2 model
story_generator = pipeline("text-generation", model="gpt2")

# Prompt for story
prompt = "The hero enters the ancient forest and discovers"

# Generate story
result = story_generator(prompt, max_length=60)

# Print generated story
print(result[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=60) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# The hero enters the ancient forest and discovers the two giant beasts are attacking his village. He attacks them with his pike and then defeats them with his sword. The two giants fall to the earth in a heap, but the hero saves them from their fate by jumping over them.
#
# On the way to the village, the hero meets a little girl named Lillie and sees that she is the daughter of an animal thief and that she lives with her father. She tells the hero that she is the daughter of a fairy and that she loves the world. She is also the daughter of a magical girl named Fennel. This girl is named Gudrun. The hero is in a dream and sees that she is the daughter of a fairy. She tells the hero that she is the daughter of a fairy and that she loves the world, and that she is the daughter of a fairy.
#
# The hero returns to the castle and saves the princess. She tells the hero that she is the daughter of a fairy and that she loves the world. She is also the daughter of a fairy.
#
# The hero leaves the castle and meets the princess and tells her that he is the daughter of a fairy. The princess tells the hero to stay away from his castle and tells him that she is the daughter

# %%
# Scenario: Research Assistant for Academic Papers
# Imagine you’re building a tool for university researchers who analyze large collections of academic papers.
# - A researcher uploads a sentence:
# “Deep learning models are powerful”
# - Your system uses the BERT tokenizer to break the sentence into smaller units (tokens).

from transformers import pipeline
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

text = "Deep learning models are powerful"

tokens = tokenizer.tokenize(text)

print(tokens)
# Out:
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# ['deep', 'learning', 'models', 'are', 'powerful']

# %%
# 🏥 Scenario: Healthcare Chatbot for Patient Queries
# A hospital is developing a chatbot to help patients ask questions about their health.
# - A patient types:
# “Deep learning models are powerful” (or in practice, something like “I have chest pain and shortness of breath”).
# - The chatbot uses the BERT tokenizer to break the sentence into tokens:

from transformers import pipeline

# Import tokenizer
from transformers import BertTokenizer

# Load BERT tokenizer
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")

# Patient query
text = "I have chest pain and shortness of breath"

# Tokenize sentence
tokens = tokenizer.tokenize(text)

# Print tokens
print(tokens)
# Out:
# ['i', 'have', 'chest', 'pain', 'and', 'short', '##ness', 'of', 'breath']

# %%
# Scenario: Exploring Creativity in AI Writing
# A university professor is running a workshop on creative writing with AI.
# - The professor gives students the prompt:
# “The future of Artificial Intelligence”
# - The system uses GPT‑2 to generate continuations of the sentence.
# To demonstrate how temperature affects creativity:
# - With temperature = 0.2 (low randomness), the output is more predictable and conservative, e.g.:
# “The future of Artificial Intelligence will bring advancements in healthcare, education, and business.”

from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

prompt = "The future of Artificial Intelligence"

print(generator(prompt, max_length=40, temperature=0.2))
print(generator(prompt, max_length=40, temperature=0.8))
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Passing `generation_config` together with generation-related arguments=({'max_length', 'temperature'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'The future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands'}]
# [{'generated_text': 'The future of Artificial Intelligence?\n\nDespite the technological advances in machine learning, the future lies in a more human-centric world. AI is currently defined as something that can be used in many different ways to do various tasks in the world, and it is important to understand what that means to humans. It is important to understand the way that artificial intelligence uses its ability to analyze human interests.\n\nMany experts across industries and in governments agree that AI has to be considered a technology at least to a certain extent, but in fact even if it can\'t, there are some parts of AI that we\'re willing to use to solve some of the most difficult problems of our day.\n\nHuman beings are incredibly capable at dealing with complex, complex tasks, and we need to move away from the simplistic notion of human being as the only "human" in an AI world.\n\nAs we have seen, the future of AI is in the future. We all must know how well our AI technologies will perform when used in the right ways. It is very good news that today Apple and Google are using their AI-powered Apple Watch to provide the same kind of high-quality, high-speed data storage and communications services as the Apple Watch. There is a lot more to this future than just'}]

# %%
#  Scenario: Scriptwriting Assistant for Film Production
# A film studio is experimenting with AI to help writers brainstorm dialogue and plot ideas.
# - The writer provides the prompt:
# “The future of Artificial Intelligence”
# - The system generates two versions of the continuation:
# - Temperature = 0.2 (low randomness)
# Output is more predictable and formal, e.g.:
# “The future of Artificial Intelligence will improve industries, enhance productivity, and reshape education.”
# → This is useful for serious, factual narration in a documentary script.
# - Temperature = 0.8 (higher randomness)
# Output is more imaginative and varied, e.g.:
# “The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.”
# → This is perfect for creative dialogue or speculative sci‑fi storytelling


# Import pipeline
from transformers import pipeline

# Load GPT-2 model
generator = pipeline("text-generation", model="gpt2")

# Writer prompt
prompt = "The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn."

# Low randomness (Temperature = 0.2)
output_low = generator(prompt, max_length=40, temperature=0.2)

# High randomness (Temperature = 0.8)
output_high = generator(prompt, max_length=40, temperature=0.8)

# Print results
print("Temperature = 0.2 Output:")
print(output_low[0]["generated_text"])

print("\nTemperature = 0.8 Output:")
print(output_high[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Temperature = 0.2 Output:
# The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.
#
# The Future of Artificial Intelligence
#
# The future of artificial intelligence is a topic that has been hotly debated for decades. In the past few years, the debate has been about whether or not we should be able to predict the future.
#
# The debate has been about whether or not we should be able to predict the future.
#
# The debate has been about whether or not we should be able to predict the future.
#
# The debate has been about whether or not we should be able to predict the future.
#
# The debate has been about whether or not we should be able to predict the future.
#
# The debate has been about whether or not we should be able to predict the future.
#
# The debate has been about whether or not we should be able to predict the future.
#
# The debate has been about whether or not we should be able to predict the future.
#
# The debate has been about whether or not we should be able to predict the future.
#
# The debate has been about whether or not we should be able to predict the future.
#
# The debate has been about whether or not we should be able to predict the future.
#
# The debate has been about whether or not we should be able to predict the future
#
# Temperature = 0.8 Output:
# The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.
#
# The Future The Future is a science fiction film released by the Warner Bros.-Columbia Pictures Group.

# %%
# Scenario: AI Model Evaluation in a Startup
# A startup is building an AI‑powered content assistant to help marketers draft product descriptions.
# - The team wants to compare two models: GPT‑2 (larger, more expressive) and DistilGPT‑2 (smaller, faster, distilled version).
# - They use the same prompt:
# “Artificial Intelligence will transform”
# - The system generates two outputs:
# - GPT‑2 Output
# Longer, more detailed continuation, e.g.:
# “Artificial Intelligence will transform industries by automating processes, enhancing creativity, and
# reshaping how humans interact with technology.”
# → Richer but slower to run.
# - DistilGPT‑2 Output


from transformers import pipeline

gpt2 = pipeline("text-generation", model="gpt2")
distilgpt2 = pipeline("text-generation", model="distilgpt2")

prompt = "Artificial Intelligence will transform"

print("GPT2:", gpt2(prompt, max_length=40))
print("DistilGPT2:", distilgpt2(prompt, max_length=40))
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: distilgpt2
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# transformer.h.{0, 1, 2, 3, 4, 5}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# GPT2: [{'generated_text': "Artificial Intelligence will transform our lives to one where we can trust the machines, we can take advantage of our digital tools and we will be able to enjoy the benefits of our digital life and our personal space.\n\nAt Google we have built a software solution that allows you to take control of a computer. That's what the Google Play Store is all about. It's where you can purchase and view your content, and you can buy and download it. We've been developing for over a decade now and we've been successful. We are not only a company, we've been a nation. We are a people.\n\nIn a sense, we are a nation. We are a country of love, and it starts with the love of God. And it is a love that is as deep, as profound, as strong as ever. It is a love that transcends race, religion, gender, sexuality, sexuality, and all other boundaries. It is a love that is about what it means to have a true human heart.\n\nWe are a nation built on love. We are a nation that is built on love. We are a nation that is built on love. We are a nation that is built on love.\n\nWe are a nation that is built on love."}]
# DistilGPT2: [{'generated_text': 'Artificial Intelligence will transform everything in this world. It›s a huge challenge.\n\n\n\nAnd what is next?\nThe real question is: will we have a truly human-powered AI? And what is the point of AI?\nIt›s a very powerful technology that can learn from its mistakes and keep us from becoming human?\nIt›s a difficult question, but that›s the answer.\nI›m not sure how to answer my question. I›m sure I›m not the answer›s answer›s answer›s answer›s answer›s answer›s answer›s answer›s answer›s answer›s answer›s answer›s answer›s answer›s answer›s answer›s answer›s answer›s answer›s answer›s answer›s answer›s answer›s answer›s answer›s answer›s answer›s answer›s answer›s answer›s answer›s answer›s answer›s answer›s answer›s answer›s answer›'}]

# %%
# Scenario: Educational Tool for Classroom Learning
# A high school teacher is introducing students to AI‑powered writing assistants.
# - The teacher wants to show how different models produce different styles of text.
# - They use the same prompt:
# “Artificial Intelligence will transform”
# - The system generates two outputs:
# - GPT‑2 Output
# More elaborate continuation, e.g.:
# “Artificial Intelligence will transform the way societies function, influencing education, healthcare, and the future of human creativity.”
# → Great for showing students how AI can generate rich, detailed ideas.
# - DistilGPT‑2 Output
# Shorter, faster continuation, e.g.:
# “Artificial Intelligence will transform our daily lives.”
# → Useful for demonstrating concise summaries

# Import pipeline
from transformers import pipeline

# Load GPT-2 model
gpt2_generator = pipeline("text-generation", model="gpt2")

# Load DistilGPT-2 model
distilgpt2_generator = pipeline("text-generation", model="distilgpt2")

# Prompt
prompt = "Artificial Intelligence will transform"

# Generate text using GPT-2
output1 = gpt2_generator(prompt, max_length=40)

# Generate text using DistilGPT-2
output2 = distilgpt2_generator(prompt, max_length=40)

# Print outputs
print("GPT-2 Output:")
print(output1[0]["generated_text"])

print("\nDistilGPT-2 Output:")
print(output2[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: distilgpt2
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# transformer.h.{0, 1, 2, 3, 4, 5}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# GPT-2 Output:
# Artificial Intelligence will transform companies into more agile, reliable and responsive, and those that rely on artificial intelligence will become more resilient and responsive, and this will make it more difficult to over-optimize, mis-evaluate or under-optimize.
#
# How does artificial intelligence have a different purpose than humans?
#
# The most obvious difference between humans and machines is that humans are much more likely to be motivated by an intelligence that is a little bit bigger than us. That is because humans are more likely to be motivated by an intelligence that is a little bit bigger than us. And that is why humans can be more likely to be motivated by an intelligence that is a little bit bigger than us.
#
# This is because humans are much more likely to be motivated by an intelligence that is about a bit larger than us. Because humans are much more likely to be motivated by an intelligence that is about a bit larger than us, it is impossible to know what human behavior will be like if it is significantly influenced by an intelligence that is about a bit larger than us.
#
# Machine Intelligence vs Artificial Intelligence
#
# What is the difference between an artificial intelligence and a human?
#
# An artificial intelligence is a machine that can be programmed using human intelligence. So if you think about it like this:
#
# DistilGPT-2 Output:
# Artificial Intelligence will transform the way we read media, and also become more aware of the challenges that come with digital media, as well as the challenges that come with digital media and the challenges that come with digital media, as well as the challenges that come with digital media.
