# %%
from google.colab import userdata

api_key = userdata.get('my_api_key')

print("API key loaded successfully")
# Out:
# API key loaded successfully

# %%
#  Scenario: AI‑Powered Email Assistant
# You’re building an email drafting assistant for a corporate team.
# - When a user starts typing:
# “Artificial Intelligence will…”
# - The assistant uses GPT‑2 to auto‑complete the sentence with a coherent continuation.
# - Example output:
# “Artificial Intelligence will transform the way businesses interact with customers,
# enabling faster decisions and personalized experiences.”

from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

print(generator("Artificial Intelligence will", max_length=30))
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Passing `generation_config` together with generation-related arguments=({'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'Artificial Intelligence will be used to drive AI more efficiently and more effectively.\n\nThe "AI Lab" – an independent, non-governmental organization created in 2002 to help advance AI research – is funded by government agencies, businesses, think tanks, and private investors. It works with the International Centre for Applied Artificial Intelligence (ICAI), the National Institute for Research on Artificial Intelligence (NRIAI), and the University of Amsterdam.\n\nIn 2014, ICAI became the world\'s first AI-driven research group led by a Dutch professor in his early 20s, and it is the world\'s first and only research arm devoted to the advancement of AI research.\n\nICAI is an extremely strong and dedicated group of researchers, which is dedicated to advancing the fundamental concepts of AI, including the role of artificial intelligence in the human experience, the role of the human mind and the role of the AI. The ICAI has developed a comprehensive set of research and development instruments for developing machine learning algorithms and algorithms, and will continue to do so. The group is a member of the IEEE International Conference on Artificial Intelligence. It is in the process of being incorporated into a new group of independent AI research institutes at the University of Applied Sciences in Amsterdam.\n\nNrija Ríos'}]

# %%
# Scenario: Game Storyline Generator
# You’re designing a fantasy role‑playing game and need quick ideas for quests and dialogue.
# - The developer types a prompt:
# “The hero enters the ancient forest and discovers…”
# - The GPT‑2 pipeline continues the story:
# “The hero enters the ancient forest and discovers a hidden village where the people whisper of
#  a cursed artifact buried beneath the old ruins.”


# Import library
from transformers import pipeline

# Load GPT-2 model
story_generator = pipeline("text-generation", model="gpt2")

# Prompt for story
prompt = "The hero enters the ancient forest and discovers"

# Generate story
result = story_generator(prompt, max_length=60)

# Print generated story
print(result[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=60) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# The hero enters the ancient forest and discovers a mysterious woman. After a moment he realizes that she's the daughter of a rich, wealthy, powerful man. He decides to take her home, but he must use the power of his powers to save her.
#
# Cult:
#
# The main story of the second season ends in the mysterious death of Lissa. She is the daughter of a wealthy, powerful, and powerful man. She has been a member of the Cult for a long time and was the first person to fall in love with a woman who was a member of the Cult. She leaves the Cult to take care of the rest of her family.
#
# Cult:
#
# The main story of the third season ends in the mysterious death of Caius. She is a powerful, powerful, and powerful man. Caius is the daughter of a wealthy, powerful, and powerful man. She has been a member of the Cult for a long time and was the first person to fall in love with a woman who was a member of the Cult. She leaves the Cult to take care of the rest of her family.
#
# Culture:
#
# The main story of the fourth season ends in the enigmatic death of Lissa. She is a powerful, powerful, and powerful man

# %%
# Scenario: Research Assistant for Academic Papers
# Imagine you’re building a tool for university researchers who analyze large collections of academic papers.
# - A researcher uploads a sentence:
# “Deep learning models are powerful”
# - Your system uses the BERT tokenizer to break the sentence into smaller units (tokens).

from transformers import pipeline
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

text = "Deep learning models are powerful"

tokens = tokenizer.tokenize(text)

print(tokens)
# Out:
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# ['deep', 'learning', 'models', 'are', 'powerful']

# %%
# 🏥 Scenario: Healthcare Chatbot for Patient Queries
# A hospital is developing a chatbot to help patients ask questions about their health.
# - A patient types:
# “Deep learning models are powerful” (or in practice, something like “I have chest pain and shortness of breath”).
# - The chatbot uses the BERT tokenizer to break the sentence into tokens:

from transformers import pipeline

# Import tokenizer
from transformers import BertTokenizer

# Load BERT tokenizer
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")

# Patient query
text = "I have chest pain and shortness of breath"

# Tokenize sentence
tokens = tokenizer.tokenize(text)

# Print tokens
print(tokens)
# Out:
# ['i', 'have', 'chest', 'pain', 'and', 'short', '##ness', 'of', 'breath']

# %%
# Scenario: Exploring Creativity in AI Writing
# A university professor is running a workshop on creative writing with AI.
# - The professor gives students the prompt:
# “The future of Artificial Intelligence”
# - The system uses GPT‑2 to generate continuations of the sentence.
# To demonstrate how temperature affects creativity:
# - With temperature = 0.2 (low randomness), the output is more predictable and conservative, e.g.:
# “The future of Artificial Intelligence will bring advancements in healthcare, education, and business.”

from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

prompt = "The future of Artificial Intelligence"

print(generator(prompt, max_length=40, temperature=0.2))
print(generator(prompt, max_length=40, temperature=0.8))
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Passing `generation_config` together with generation-related arguments=({'temperature', 'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'The future of Artificial Intelligence is in the hands of the next generation of scientists.\n\nThe next generation of AI will be able to understand and understand the world around us, and will be able to solve problems that we have not yet solved.\n\nThe next generation of AI will be able to solve problems that we have not yet solved.\n\nThe next generation of AI will be able to solve problems that we have not yet solved.\n\nThe next generation of AI will be able to solve problems that we have not yet solved.\n\nThe next generation of AI will be able to solve problems that we have not yet solved.\n\nThe next generation of AI will be able to solve problems that we have not yet solved.\n\nThe next generation of AI will be able to solve problems that we have not yet solved.\n\nThe next generation of AI will be able to solve problems that we have not yet solved.\n\nThe next generation of AI will be able to solve problems that we have not yet solved.\n\nThe next generation of AI will be able to solve problems that we have not yet solved.\n\nThe next generation of AI will be able to solve problems that we have not yet solved.\n\nThe next generation of AI will be able to solve'}]
# [{'generated_text': 'The future of Artificial Intelligence could be in a few years.\n\n"You\'ve got to keep dreaming. It\'s not going to happen overnight," said Michael Spillane, a professor of computer science and computer vision at Stanford University. "It\'s going to happen in a few less years."'}]

# %%
#  Scenario: Scriptwriting Assistant for Film Production
# A film studio is experimenting with AI to help writers brainstorm dialogue and plot ideas.
# - The writer provides the prompt:
# “The future of Artificial Intelligence”
# - The system generates two versions of the continuation:
# - Temperature = 0.2 (low randomness)
# Output is more predictable and formal, e.g.:
# “The future of Artificial Intelligence will improve industries, enhance productivity, and reshape education.”
# → This is useful for serious, factual narration in a documentary script.
# - Temperature = 0.8 (higher randomness)
# Output is more imaginative and varied, e.g.:
# “The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.”
# → This is perfect for creative dialogue or speculative sci‑fi storytelling


# Import pipeline
from transformers import pipeline

# Load GPT-2 model
generator = pipeline("text-generation", model="gpt2")

# Writer prompt
prompt = "The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn."

# Low randomness (Temperature = 0.2)
output_low = generator(prompt, max_length=40, temperature=0.2)

# High randomness (Temperature = 0.8)
output_high = generator(prompt, max_length=40, temperature=0.8)

# Print results
print("Temperature = 0.2 Output:")
print(output_low[0]["generated_text"])

print("\nTemperature = 0.8 Output:")
print(output_high[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Temperature = 0.2 Output:
# The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.
#
# The Future of Artificial Intelligence
#
# The Future of Artificial Intelligence
#
# The Future of Artificial Intelligence
#
# The Future of Artificial Intelligence
#
# The Future of Artificial Intelligence
#
# The Future of Artificial Intelligence
#
# The Future of Artificial Intelligence
#
# The Future of Artificial Intelligence
#
# The Future of Artificial Intelligence
#
# The Future of Artificial Intelligence
#
# The Future of Artificial Intelligence
#
# The Future of Artificial Intelligence
#
# The Future of Artificial Intelligence
#
# The Future of Artificial Intelligence
#
# The Future of Artificial Intelligence
#
# The Future of Artificial Intelligence
#
# The Future of Artificial Intelligence
#
# The Future of Artificial Intelligence
#
# The Future of Artificial Intelligence
#
# The Future of Artificial Intelligence
#
# The Future of Artificial Intelligence
#
# The Future of Artificial Intelligence
#
# The Future of Artificial Intelligence
#
# The Future of Artificial Intelligence
#
# The Future of Artificial Intelligence
#
# The Future of Artificial Intelligence
#
# The Future of Artificial Intelligence
#
# The Future of Artificial Intelligence
#
# The Future of Artificial Intelligence
#
# The Future of Artificial Intelligence
#
# The Future of Artificial Intelligence
#
# The Future of Artificial Intelligence
#
# The Future of Artificial Intelligence
#
# The Future of Artificial Intelligence
#
# The Future of Artificial Intelligence
#
# The Future of Artificial Intelligence
#
# The Future
#
# Temperature = 0.8 Output:
# The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.
#
# The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.
#
# In The Great Singularity, Richard Dawkins (The New Atheist) says
#
# "An AI would be as much a technological advance as the human equivalent of Einstein's great general theory of relativity." That's because, as the writer of 'The Self-Taught Teacher' tells it, AI is "a process of learning, but of learning and learning continually, not always in the most natural way". Now that's a very good, naturalistic proposition, Dawkins agrees.
#
# But there's one big problem with Dawkins's theory of AI, it turns out, and that's that it doesn't explain the difference between humans and machines.
#
# For the most part, we know where the differences are because there's no artificial intelligence at play here. As AI is driven by its computer skills and human-like intelligence, which is clearly not a feature of the human race, there's little evidence that we can really explain that.
#
# In fact, we know that when we talk about AI and the machine that is the one being built, we're talking about AI only being a tool of human intelligence. It's not even mentioned in the book '

# %%
# Scenario: AI‑Powered News Headline Generator
# A digital media company wants to help journalists brainstorm headlines and opening lines for articles.
# - The system asks the journalist to enter a prompt (e.g., “Enter a prompt: The future of Artificial Intelligence”).
# - The GPT‑2 model then generates a continuation of the text, up to 50 tokens.
# - Example output:
# “The future of Artificial Intelligence will reshape industries, redefine creativity, and challenge
#  our understanding of human potential.”

from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

prompt = input("Enter a prompt: ")

output = generator(prompt, max_length=50)

print(output[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Enter a prompt: The future of Artificial Intelligence will reshape industries, redefine creativity, and challenge our understanding of human potential
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# The future of Artificial Intelligence will reshape industries, redefine creativity, and challenge our understanding of human potential.
#
# The Future of Artificial Intelligence will reshape industries, redefine creativity, and challenge our understanding of human potential. Artificial Intelligence will improve health, prevent disease, and preserve human life.
#
# AI will be the next step in the evolution of the human race, and the future of the human race. Artificial Intelligence will bring the scientific advances of our age and enhance human life.
#
# AI will provide the first real tools for people to interact with the world around them, and it will provide the first real tools for people to interact with the world around them, and it will provide the first real tools for people to interact with the world around them, and it will provide the first real tools for people to interact with the world around them, and it will provide the first real tools for people to interact with the world around them, and it will provide the first real tools for people to interact with the world around them, and it will provide the first real tools for people to interact with the world around them, and it will provide the first real tools for people to interact with the world around them, and it will provide the first real tools for people to interact with the world around them, and it will provide the first real tools for people to interact with the world

# %%
# 🎓 Scenario: Student Brainstorming Tool for Essay Writing
# A college student is struggling to start their essay.
# - The system prompts them:
# “Enter a prompt:”
# - The student types:
# “The impact of technology on education”
# - The GPT‑2 model generates a continuation up to 50 tokens, for example:
# “The impact of technology on education has transformed classrooms, enabling online learning,
# personalized study plans, and global collaboration among students.”

# Import pipeline
from transformers import pipeline

# Load GPT-2 model
generator = pipeline("text-generation", model="gpt2")

# Ask student to enter prompt
prompt = input("Enter a prompt: ")

# Generate essay continuation (50 tokens)
result = generator(prompt, max_length=50)

# Print generated text
print("\nGenerated Essay Idea:")
print(result[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Enter a prompt: The impact of technology on education
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generated Essay Idea:
# The impact of technology on education has been discussed extensively. What is clear is that there is much more to the education of children than what is learned in a classroom. Technology can, in some cases, even change the way that we learn, the way we get better at something.
#
# For one thing, if technology is truly the future of education, why does it seem to be so difficult for parents to learn about technology when they are already in high school? Why have parents and teachers so often refused to pay attention to the technical aspects of technology? Why do I hear so many parents talk so little about the potential benefits of education and how this can contribute to their children's well-being?
#
# Some might argue that technological education has become more important in the last few decades because technology has brought more opportunities for the younger generations to learn and to improve. Why? Because we have more children in high school than in any other generation, and because we have more children in high school than in any other generation. However, it is true that technological achievement has been improved on a number of generations, from the very early days of the Industrial Revolution to the present. Technology and innovation are now more important than ever:
#
# The percentage of students who achieve at least one grade point average higher than their peers

# %%
# Scenario: AI Model Evaluation in a Startup
# A startup is building an AI‑powered content assistant to help marketers draft product descriptions.
# - The team wants to compare two models: GPT‑2 (larger, more expressive) and DistilGPT‑2 (smaller, faster, distilled version).
# - They use the same prompt:
# “Artificial Intelligence will transform”
# - The system generates two outputs:
# - GPT‑2 Output
# Longer, more detailed continuation, e.g.:
# “Artificial Intelligence will transform industries by automating processes, enhancing creativity, and
# reshaping how humans interact with technology.”
# → Richer but slower to run.
# - DistilGPT‑2 Output


from transformers import pipeline

gpt2 = pipeline("text-generation", model="gpt2")
distilgpt2 = pipeline("text-generation", model="distilgpt2")

prompt = "Artificial Intelligence will transform"

print("GPT2:", gpt2(prompt, max_length=40))
print("DistilGPT2:", distilgpt2(prompt, max_length=40))
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: distilgpt2
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# transformer.h.{0, 1, 2, 3, 4, 5}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# GPT2: [{'generated_text': 'Artificial Intelligence will transform the way we live.\n\nThe idea is that we will become more intelligent and able to create and share knowledge, and thus more useful. This will make our lives easier for us.'}]
# DistilGPT2: [{'generated_text': 'Artificial Intelligence will transform the way we approach the world today, as it is today.\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n'}]

# %%
# Scenario: Educational Tool for Classroom Learning
# A high school teacher is introducing students to AI‑powered writing assistants.
# - The teacher wants to show how different models produce different styles of text.
# - They use the same prompt:
# “Artificial Intelligence will transform”
# - The system generates two outputs:
# - GPT‑2 Output
# More elaborate continuation, e.g.:
# “Artificial Intelligence will transform the way societies function, influencing education, healthcare, and the future of human creativity.”
# → Great for showing students how AI can generate rich, detailed ideas.
# - DistilGPT‑2 Output
# Shorter, faster continuation, e.g.:
# “Artificial Intelligence will transform our daily lives.”
# → Useful for demonstrating concise summaries

# Import pipeline
from transformers import pipeline

# Load GPT-2 model
gpt2_generator = pipeline("text-generation", model="gpt2")

# Load DistilGPT-2 model
distilgpt2_generator = pipeline("text-generation", model="distilgpt2")

# Prompt
prompt = "Artificial Intelligence will transform"

# Generate text using GPT-2
output1 = gpt2_generator(prompt, max_length=40)

# Generate text using DistilGPT-2
output2 = distilgpt2_generator(prompt, max_length=40)

# Print outputs
print("GPT-2 Output:")
print(output1[0]["generated_text"])

print("\nDistilGPT-2 Output:")
print(output2[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: distilgpt2
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# transformer.h.{0, 1, 2, 3, 4, 5}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# GPT-2 Output:
# Artificial Intelligence will transform the way we think about things around us. Artificial Intelligence will change the way we think about our own lives, and we'll be able to better understand these interactions and how they work.
#
#
# The real-life future of AI will be in the next decade. AI is already making predictions about the future of living people, but we need to be aware of how things work that we can use to help us navigate those patterns. We need to be able to predict the future. That's where Artificial Intelligence comes in.
#
#
# From what I've seen, it's clear that AI is a big deal. It's going to be a big deal when it comes to what we do and how we learn about it. We need to be able to predict what we'll look like and what's happening in the world we live in, and to make that prediction possible.
#
#
# What's next?
#
#
# In the next couple of months we'll start to see some large-scale breakthroughs in the areas of human knowledge and our ability to think in the real world. It will be interesting to see how this progresses and where it leads.
#
#
# What's your understanding of the deep learning that's been going on at Carnegie Mellon, and how it's being applied to AI
#
# DistilGPT-2 Output:
# Artificial Intelligence will transform the world‒s finances and society, by giving them a much better understanding of the challenges facing the planet—and the benefits they can reap.
#
#
#
#
#
# The research team is not the first to study how artificial intelligence can make things better for the planet. The results from a recent survey of 1,300 people in the United States, published in the journal Science and Engineering, show that the results are quite promising—they are even more promising than the ones we‒ve already seen in the past.
#
# The team also examined the consequences of AI technology and its use in medicine (including for obesity and diabetes) and in the health and welfare of the planet.
# Scientists have been exploring how artificial intelligence can improve the lives of people, but they're still far from sure that it can be the most effective way to improve the lives of humankind.
# Now, the team is working to uncover the causes of this new research:
# It turns out that AI technology can do a lot better than previous research, but the results of the study are still far from sure.
# It also looks like AI technology could be able to provide better services and services for people with a disability.
# This is the first study to look at how artificial intelligence can improve
