# %%
# !pip install gradio
# Out:
# Requirement already satisfied: gradio in /usr/local/lib/python3.12/dist-packages (5.50.0)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (4.12.1)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.135.1)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.12/dist-packages (from gradio) (1.0.0)
# Requirement already satisfied: gradio-client==1.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (1.14.0)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.33.5 in /usr/local/lib/python3.12/dist-packages (from gradio) (1.7.1)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (3.0.3)
# Requirement already satisfied: numpy<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (2.0.2)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (3.11.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from gradio) (26.0)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (2.2.2)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (11.3.0)
# Requirement already satisfied: pydantic<=2.12.3,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (2.12.3)
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.0.22)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (6.0.3)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.15.6)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.52.1)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.24.1)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (4.15.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.42.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.14.0->gradio) (2025.3.0)
# Requirement already satisfied: websockets<16.0,>=13.0 in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.14.0->gradio) (15.0.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0,>=3.0->gradio) (3.11)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1.0,>=0.115.2->gradio) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1.0,>=0.115.2->gradio) (0.0.4)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (3.25.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (1.4.2)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (4.67.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio) (2025.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<=2.12.3,>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<=2.12.3,>=2.0->gradio) (2.41.4)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio) (13.9.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer<1.0,>=0.12->gradio) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer<1.0,>=0.12->gradio) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer<1.0,>=0.12->gradio) (0.1.2)

# %%
# SCENARIO: “College Smart Assistant System”
# Background Story

# A college builds an AI-powered student assistant.

# Students can ask:

# “What is my attendance?”
# “What are my marks?”

# Instead of manually checking portals,
# AI fetches it instantly.


# ================================
# STEP 1: Dummy Database (Tool Layer)
# ================================
students = {
    "101": {"name": "Rahul", "attendance": 85, "marks": 78},
    "102": {"name": "Priya", "attendance": 92, "marks": 88}
}


# ================================
# STEP 2: Tool Functions (MCP Tools)
# ================================
def get_attendance(student_id):
    if student_id in students:
        return f" Attendance: {students[student_id]['attendance']}%"
    return " Student not found"


def get_marks(student_id):
    if student_id in students:
        return f" Marks: {students[student_id]['marks']}"
    return " Student not found"


# ================================
# STEP 3: Security Layer
# ================================
def secure_access(user_id, requested_id):
    return user_id == requested_id


# ================================
# STEP 4: MCP Agent Logic
# ================================
def mcp_agent(message, student_id, history):

    # Simulate logged-in user (for demo)
    user_id = student_id

    # Security Check
    if not secure_access(user_id, student_id):
        return " Access Denied", history

    # Tool Invocation Logic
    message_lower = message.lower()

    if "attendance" in message_lower:
        response = get_attendance(student_id)

    elif "marks" in message_lower:
        response = get_marks(student_id)

    elif "hello" in message_lower or "hi" in message_lower:
        response = " Hello! Ask me about attendance or marks."

    else:
        response = " I can help with attendance or marks."

    # Maintain chat history
    history.append((message, response))

    return "", history


# ================================
# STEP 5: Gradio Chat UI
# ================================
import gradio as gr

with gr.Blocks() as demo:

    gr.Markdown("#  Student MCP Agent (Gradio Version)")

    student_id = gr.Textbox(label="Enter Student ID (e.g., 101)")

    chatbot = gr.Chatbot()
    msg = gr.Textbox(label="Ask your question")

    state = gr.State([])

    msg.submit(
        mcp_agent,
        inputs=[msg, student_id, state],
        outputs=[msg, chatbot]
    )

# ================================
# STEP 6: Launch App (Public URL)
# ================================
demo.launch(share=True)
# Out:
# /tmp/ipykernel_4045/3253206472.py:90: UserWarning: You have not specified a value for the `type` parameter. Defaulting to the 'tuples' format for chatbot messages, but this is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style dictionaries with 'role' and 'content' keys.
#   chatbot = gr.Chatbot()
# /tmp/ipykernel_4045/3253206472.py:90: DeprecationWarning: The default value of 'allow_tags' in gr.Chatbot will be changed from False to True in Gradio 6.0. You will need to explicitly set allow_tags=False if you want to disable tags in your chatbot.
#   chatbot = gr.Chatbot()
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://600d1288bb9c8368f5.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://600d1288bb9c8368f5.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# SCENARIO: “Hospital Smart Assistant System”
# Background Story
# A large hospital deploys an AI-powered patient assistant.
# Patients can ask:
# - “What is my appointment schedule?”
# - “What are my latest test results?”
# Instead of calling reception or logging into multiple portals,
# AI fetches it instantly, providing secure, real-time updates.


# ================================
# STEP 1: Dummy Database (Hospital Data)
# ================================
patients = {
    "201": {
        "name": "Amit",
        "appointments": ["10 AM - Dr. Sharma", "3 PM - Blood Test"],
        "reports": "Blood Test: Normal"
    },
    "202": {
        "name": "Neha",
        "appointments": ["12 PM - Dr. Mehta"],
        "reports": "X-Ray: Minor fracture"
    },
    "203": {
        "name": "Sonali",
        "appointments": ["3 PM - Dr. Verma"],
        "reports": "Hypertension: Normal"
    }
}


# ================================
# STEP 2: Tool Functions (MCP Tools)
# ================================
def get_appointments(patient_id):
    if patient_id in patients:
        return " Appointments:\n" + "\n".join(patients[patient_id]["appointments"])
    return " Patient not found"


def get_reports(patient_id):
    if patient_id in patients:
        return f" Reports:\n{patients[patient_id]['reports']}"
    return " Patient not found"


# ================================
# STEP 3: Security Layer
# ================================
def secure_access(user_id, requested_id):
    return user_id == requested_id


# ================================
# STEP 4: MCP Agent Logic
# ================================
def mcp_agent(message, patient_id, history):

    # Simulated logged-in user
    user_id = patient_id

    # Security Check
    if not secure_access(user_id, patient_id):
        return " Access Denied", history

    message_lower = message.lower()

    # Tool Invocation
    if "appointment" in message_lower:
        response = get_appointments(patient_id)

    elif "report" in message_lower or "test" in message_lower:
        response = get_reports(patient_id)

    elif "hello" in message_lower or "hi" in message_lower:
        response = " Hello! I can help with appointments and reports."

    else:
        response = " Ask me about appointments or test results."

    # Update chat history
    history.append((message, response))

    return "", history


# ================================
# STEP 5: Gradio Chat UI
# ================================
import gradio as gr

with gr.Blocks() as demo:

    gr.Markdown("#  Hospital Smart Assistant (MCP)")

    patient_id = gr.Textbox(label="Enter Patient ID (e.g., 201)")

    chatbot = gr.Chatbot()
    msg = gr.Textbox(label="Ask your question")

    state = gr.State([])

    msg.submit(
        mcp_agent,
        inputs=[msg, patient_id, state],
        outputs=[msg, chatbot]
    )


# ================================
# STEP 6: Launch App
# ================================
demo.launch(share=True)
# Out:
# /tmp/ipykernel_4045/143319779.py:99: UserWarning: You have not specified a value for the `type` parameter. Defaulting to the 'tuples' format for chatbot messages, but this is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style dictionaries with 'role' and 'content' keys.
#   chatbot = gr.Chatbot()
# /tmp/ipykernel_4045/143319779.py:99: DeprecationWarning: The default value of 'allow_tags' in gr.Chatbot will be changed from False to True in Gradio 6.0. You will need to explicitly set allow_tags=False if you want to disable tags in your chatbot.
#   chatbot = gr.Chatbot()
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://fe0848ef46c40b70d9.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://fe0848ef46c40b70d9.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# SCENARIO: “Banking Smart Assistant System”
# Background Story
# A major bank launches an AI-powered customer assistant.
# Customers can ask:
# - “What is my account balance?”
# - “Show me my last 5 transactions.”
# - “When is my loan EMI due?”
# Instead of logging into apps or waiting on customer service calls,
# AI fetches the information instantly, securely, and in real time.

# Core Idea:
# Just like the hospital and college scenarios, the assistant removes manual checking, centralizes financial data, and makes access instant.
# Impact:
# - Saves customers time.
# - Reduces load on call centers.
# - Provides personalized financial insights on demand.


# ================================
# STEP 1: Dummy Database (Bank Data)
# ================================
customers = {
    "301": {
        "name": "Rahul",
        "balance": 25000,
        "transactions": ["₹500 - Grocery", "₹2000 - Shopping", "₹1500 - Electricity"],
        "loan": "EMI ₹5000 due on 5th April"
    },
    "302": {
        "name": "Priya",
        "balance": 42000,
        "transactions": ["₹1000 - Recharge", "₹3000 - Rent", "₹800 - Food"],
        "loan": "EMI ₹7000 due on 10th April"
    }
}


# ================================
# STEP 2: Tool Functions (MCP Tools)
# ================================
def get_balance(user_id):
    if user_id in customers:
        return f" Balance: ₹{customers[user_id]['balance']}"
    return " Customer not found"


def get_transactions(user_id):
    if user_id in customers:
        return " Last Transactions:\n" + "\n".join(customers[user_id]["transactions"])
    return " Customer not found"


def get_loan(user_id):
    if user_id in customers:
        return f" Loan Info:\n{customers[user_id]['loan']}"
    return " Customer not found"


# ================================
# STEP 3: Security Layer
# ================================
def secure_access(user_id, requested_id):
    return user_id == requested_id


# ================================
# STEP 4: MCP Agent Logic
# ================================
def mcp_agent(message, user_id, history):

    # Simulated logged-in user
    current_user = user_id

    # Security Check
    if not secure_access(current_user, user_id):
        return " Access Denied", history

    message_lower = message.lower()

    # Tool Invocation
    if "balance" in message_lower:
        response = get_balance(user_id)

    elif "transaction" in message_lower:
        response = get_transactions(user_id)

    elif "loan" in message_lower or "emi" in message_lower:
        response = get_loan(user_id)

    elif "hello" in message_lower or "hi" in message_lower:
        response = " Hello! I can help with balance, transactions, and loan details."

    else:
        response = " Ask me about balance, transactions, or loan."

    # Update chat history
    history.append((message, response))

    return "", history


# ================================
# STEP 5: Gradio Chat UI
# ================================
import gradio as gr

with gr.Blocks() as demo:

    gr.Markdown("#  Banking Smart Assistant (MCP)")

    user_id = gr.Textbox(label="Enter Customer ID (e.g., 301)")

    chatbot = gr.Chatbot()
    msg = gr.Textbox(label="Ask your question")

    state = gr.State([])

    msg.submit(
        mcp_agent,
        inputs=[msg, user_id, state],
        outputs=[msg, chatbot]
    )


# ================================
# STEP 6: Launch App
# ================================
demo.launch(share=True)
# Out:
# /tmp/ipykernel_4045/1548373200.py:113: UserWarning: You have not specified a value for the `type` parameter. Defaulting to the 'tuples' format for chatbot messages, but this is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style dictionaries with 'role' and 'content' keys.
#   chatbot = gr.Chatbot()
# /tmp/ipykernel_4045/1548373200.py:113: DeprecationWarning: The default value of 'allow_tags' in gr.Chatbot will be changed from False to True in Gradio 6.0. You will need to explicitly set allow_tags=False if you want to disable tags in your chatbot.
#   chatbot = gr.Chatbot()
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://9f7c0ead6148e9728e.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://9f7c0ead6148e9728e.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# !pip install groq gradio
# Out:
# Collecting groq
#   Downloading groq-1.1.2-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: gradio in /usr/local/lib/python3.12/dist-packages (5.50.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from groq) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from groq) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /usr/local/lib/python3.12/dist-packages (from groq) (4.15.0)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (24.1.0)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.135.1)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.12/dist-packages (from gradio) (1.0.0)
# Requirement already satisfied: gradio-client==1.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (1.14.0)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.33.5 in /usr/local/lib/python3.12/dist-packages (from gradio) (1.7.1)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (3.0.3)
# Requirement already satisfied: numpy<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (2.0.2)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (3.11.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from gradio) (26.0)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (2.2.2)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (11.3.0)
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.0.22)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (6.0.3)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.15.6)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.52.1)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.24.1)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.42.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.14.0->gradio) (2025.3.0)
# Requirement already satisfied: websockets<16.0,>=13.0 in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.14.0->gradio) (15.0.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->groq) (3.11)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1.0,>=0.115.2->gradio) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1.0,>=0.115.2->gradio) (0.0.4)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.16.0)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (3.25.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (1.4.2)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (4.67.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio) (2025.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (2.41.4)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio) (13.9.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer<1.0,>=0.12->gradio) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer<1.0,>=0.12->gradio) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Downloading groq-1.1.2-py3-none-any.whl (141 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.7/141.7 kB 3.5 MB/s eta 0:00:00
# Installing collected packages: groq
# Successfully installed groq-1.1.2

# %%
# LLM Integration for first scenario
# SCENARIO: “College Smart Assistant System”
# Background Story

# A college builds an AI-powered student assistant.

# Students can ask:

# “What is my attendance?”
# “What are my marks?”

# Instead of manually checking portals,
# AI fetches it instantly.


# ======================================
# STEP 1: Load API Key from Colab Secrets
# ======================================
from google.colab import userdata

groq_api_key = userdata.get("token")

from groq import Groq
client = Groq(api_key=groq_api_key)


# ======================================
# STEP 2: Dummy Database (Tool Layer)
# ======================================
students = {
    "101": {"name": "Rahul", "attendance": 85, "marks": 78},
    "102": {"name": "Priya", "attendance": 92, "marks": 88}
}


# ======================================
# STEP 3: Tool Functions
# ======================================
def get_attendance(student_id):
    if student_id in students:
        return f" Attendance: {students[student_id]['attendance']}%"
    return " Student not found"


def get_marks(student_id):
    if student_id in students:
        return f" Marks: {students[student_id]['marks']}"
    return " Student not found"


# ======================================
# STEP 4: MCP Tool Decision via LLM
# ======================================
def decide_tool(query):
    try:
        prompt = f"""
        You are an AI assistant.

        Decide which function to call:
        - get_attendance
        - get_marks

        Rules:
        - If user asks about attendance → get_attendance
        - If user asks about marks → get_marks

        Only return function name.

        Query: {query}
        """

        response = client.chat.completions.create(
            model="llama-3.3-70b-versatile",
            messages=[{"role": "user", "content": prompt}]
        )

        tool = response.choices[0].message.content.strip().lower()

        return tool

    except Exception as e:
        print(" Groq Error:", e)
        return "fallback"


# ======================================
# STEP 5: MCP Agent (CORE LOGIC)
# ======================================
def mcp_agent(message, student_id, history):

    # Validate input
    if not student_id:
        response = " Please enter Student ID"
        history.append((message, response))
        return "", history

    # Step 1: LLM decides tool
    tool = decide_tool(message)

    # Step 2: Tool Invocation
    if "attendance" in tool:
        response = get_attendance(student_id)

    elif "marks" in tool:
        response = get_marks(student_id)

    # Fallback (if LLM fails)
    elif tool == "fallback":
        if "attendance" in message.lower():
            response = get_attendance(student_id)
        elif "marks" in message.lower():
            response = get_marks(student_id)
        else:
            response = " LLM failed, and I couldn't understand."

    else:
        response = " I can help with attendance or marks."

    # Step 3: Save chat
    history.append((message, response))

    return "", history


# ======================================
# STEP 6: Gradio UI
# ======================================
import gradio as gr

with gr.Blocks() as demo:

    gr.Markdown("#  MCP Agent with Groq (Stable Version)")

    student_id = gr.Textbox(label="Enter Student ID (101 / 102)")

    chatbot = gr.Chatbot(height=400)
    msg = gr.Textbox(label="Ask your question")

    state = gr.State([])

    msg.submit(
        mcp_agent,
        inputs=[msg, student_id, state],
        outputs=[msg, chatbot]
    )


# ======================================
# STEP 7: Launch App
# ======================================
demo.launch(share=True)
# Out:
# /tmp/ipykernel_4045/445250062.py:136: UserWarning: You have not specified a value for the `type` parameter. Defaulting to the 'tuples' format for chatbot messages, but this is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style dictionaries with 'role' and 'content' keys.
#   chatbot = gr.Chatbot(height=400)
# /tmp/ipykernel_4045/445250062.py:136: DeprecationWarning: The default value of 'allow_tags' in gr.Chatbot will be changed from False to True in Gradio 6.0. You will need to explicitly set allow_tags=False if you want to disable tags in your chatbot.
#   chatbot = gr.Chatbot(height=400)
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://4b7bedb137727ebd12.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://4b7bedb137727ebd12.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
#LLM Integration for second scenario
# SCENARIO: “Hospital Smart Assistant System”
# Background Story
# A large hospital deploys an AI-powered patient assistant.
# Patients can ask:
# - “What is my appointment schedule?”
# - “What are my latest test results?”
# Instead of calling reception or logging into multiple portals,
# AI fetches it instantly, providing secure, real-time updates.


# ======================================
# STEP 1: Load API Key from Colab Secrets
# ======================================
from google.colab import userdata

groq_api_key = userdata.get("token")

from groq import Groq
client = Groq(api_key=groq_api_key)


# ======================================
# STEP 2: Dummy Database (Hospital Data)
# ======================================
patients = {
    "201": {
        "name": "Amit",
        "appointments": ["10 AM - Dr. Sharma", "3 PM - Blood Test"],
        "reports": "Blood Test: Normal"
    },
    "202": {
        "name": "Neha",
        "appointments": ["12 PM - Dr. Mehta"],
        "reports": "X-Ray: Minor fracture"
    }
}


# ======================================
# STEP 3: Tool Functions
# ======================================
def get_appointments(patient_id):
    if patient_id in patients:
        return " Appointments:\n" + "\n".join(patients[patient_id]["appointments"])
    return " Patient not found"


def get_reports(patient_id):
    if patient_id in patients:
        return f" Reports:\n{patients[patient_id]['reports']}"
    return " Patient not found"


# ======================================
# STEP 4: MCP Tool Decision via LLM
# ======================================
def decide_tool(query):
    try:
        prompt = f"""
        You are a hospital assistant.

        Decide which function to call:
        - get_appointments
        - get_reports

        Rules:
        - If user asks about appointment → get_appointments
        - If user asks about report/test → get_reports

        Only return function name.

        Query: {query}
        """

        response = client.chat.completions.create(
            model="llama-3.3-70b-versatile",
            messages=[{"role": "user", "content": prompt}],
            temperature=0
        )

        tool = response.choices[0].message.content.strip().lower()

        return tool

    except Exception as e:
        print(" Groq Error:", e)
        return "fallback"


# ======================================
# STEP 5: MCP Agent (CORE LOGIC)
# ======================================
def mcp_agent(message, patient_id, history):

    # Validate input
    if not patient_id:
        response = " Please enter Patient ID"
        history.append((message, response))
        return "", history

    # Step 1: LLM decides tool
    tool = decide_tool(message)

    # Step 2: Tool Invocation
    if "appointment" in tool:
        response = get_appointments(patient_id)

    elif "report" in tool:
        response = get_reports(patient_id)

    # Fallback (if LLM fails)
    elif tool == "fallback":
        if "appointment" in message.lower():
            response = get_appointments(patient_id)
        elif "report" in message.lower() or "test" in message.lower():
            response = get_reports(patient_id)
        else:
            response = " LLM failed, and I couldn't understand."

    else:
        response = " I can help with appointments and reports."

    # Step 3: Save chat
    history.append((message, response))

    return "", history


# ======================================
# STEP 6: Gradio UI
# ======================================
import gradio as gr

with gr.Blocks() as demo:

    gr.Markdown("#  Hospital Smart Assistant (LLM + MCP)")

    patient_id = gr.Textbox(label="Enter Patient ID (201 / 202)")

    chatbot = gr.Chatbot(height=400)
    msg = gr.Textbox(label="Ask your question")

    state = gr.State([])

    msg.submit(
        mcp_agent,
        inputs=[msg, patient_id, state],
        outputs=[msg, chatbot]
    )


# ======================================
# STEP 7: Launch App
# ======================================
demo.launch(share=True)
# Out:
# /tmp/ipykernel_4045/2843584002.py:141: UserWarning: You have not specified a value for the `type` parameter. Defaulting to the 'tuples' format for chatbot messages, but this is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style dictionaries with 'role' and 'content' keys.
#   chatbot = gr.Chatbot(height=400)
# /tmp/ipykernel_4045/2843584002.py:141: DeprecationWarning: The default value of 'allow_tags' in gr.Chatbot will be changed from False to True in Gradio 6.0. You will need to explicitly set allow_tags=False if you want to disable tags in your chatbot.
#   chatbot = gr.Chatbot(height=400)
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://01f97d08d3e12cc3b6.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://01f97d08d3e12cc3b6.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
#LLM Integration for third scenario
# SCENARIO: “Banking Smart Assistant System”
# Background Story
# A major bank launches an AI-powered customer assistant.
# Customers can ask:
# - “What is my account balance?”
# - “Show me my last 5 transactions.”
# - “When is my loan EMI due?”
# Instead of logging into apps or waiting on customer service calls,
# AI fetches the information instantly, securely, and in real time.

# Core Idea:
# Just like the hospital and college scenarios, the assistant removes manual checking, centralizes financial data, and makes access instant.
# Impact:
# - Saves customers time.
# - Reduces load on call centers.
# - Provides personalized financial insights on demand.


# ======================================
# STEP 1: Load API Key from Colab Secrets
# ======================================
from google.colab import userdata

groq_api_key = userdata.get("token")

from groq import Groq
client = Groq(api_key=groq_api_key)


# ======================================
# STEP 2: Dummy Database (Bank Data)
# ======================================
customers = {
    "301": {
        "name": "Rahul",
        "balance": 25000,
        "transactions": ["₹500 - Grocery", "₹2000 - Shopping", "₹1500 - Electricity"],
        "loan": "EMI ₹5000 due on 5th April"
    },
    "302": {
        "name": "Priya",
        "balance": 42000,
        "transactions": ["₹1000 - Recharge", "₹3000 - Rent", "₹800 - Food"],
        "loan": "EMI ₹7000 due on 10th April"
    }
}


# ======================================
# STEP 3: Tool Functions
# ======================================
def get_balance(user_id):
    if user_id in customers:
        return f" Balance: ₹{customers[user_id]['balance']}"
    return " Customer not found"


def get_transactions(user_id):
    if user_id in customers:
        return " Last Transactions:\n" + "\n".join(customers[user_id]["transactions"])
    return " Customer not found"


def get_loan(user_id):
    if user_id in customers:
        return f" Loan Info:\n{customers[user_id]['loan']}"
    return " Customer not found"


# ======================================
# STEP 4: MCP Tool Decision via LLM
# ======================================
def decide_tool(query):
    try:
        prompt = f"""
        You are a banking assistant.

        Decide which function to call:
        - get_balance
        - get_transactions
        - get_loan

        Rules:
        - If user asks about balance → get_balance
        - If user asks about transactions → get_transactions
        - If user asks about loan/EMI → get_loan

        Only return function name.

        Query: {query}
        """

        response = client.chat.completions.create(
            model="llama-3.3-70b-versatile",
            messages=[{"role": "user", "content": prompt}],
            temperature=0
        )

        tool = response.choices[0].message.content.strip().lower()

        return tool

    except Exception as e:
        print(" Groq Error:", e)
        return "fallback"


# ======================================
# STEP 5: MCP Agent (CORE LOGIC)
# ======================================
def mcp_agent(message, user_id, history):

    # Validate input
    if not user_id:
        response = " Please enter Customer ID"
        history.append((message, response))
        return "", history

    # Step 1: LLM decides tool
    tool = decide_tool(message)

    # Step 2: Tool Invocation
    if "balance" in tool:
        response = get_balance(user_id)

    elif "transaction" in tool:
        response = get_transactions(user_id)

    elif "loan" in tool or "emi" in tool:
        response = get_loan(user_id)

    # Fallback (if LLM fails)
    elif tool == "fallback":
        if "balance" in message.lower():
            response = get_balance(user_id)
        elif "transaction" in message.lower():
            response = get_transactions(user_id)
        elif "loan" in message.lower() or "emi" in message.lower():
            response = get_loan(user_id)
        else:
            response = " LLM failed, and I couldn't understand."

    else:
        response = " I can help with balance, transactions, and loan details."

    # Step 3: Save chat
    history.append((message, response))

    return "", history


# ======================================
# STEP 6: Gradio UI
# ======================================
import gradio as gr

with gr.Blocks() as demo:

    gr.Markdown("#  Banking Smart Assistant (LLM + MCP)")

    user_id = gr.Textbox(label="Enter Customer ID (301 / 302)")

    chatbot = gr.Chatbot(height=400)
    msg = gr.Textbox(label="Ask your question")

    state = gr.State([])

    msg.submit(
        mcp_agent,
        inputs=[msg, user_id, state],
        outputs=[msg, chatbot]
    )


# ======================================
# STEP 7: Launch App
# ======================================
demo.launch(share=True)
# Out:
# /tmp/ipykernel_4045/1383457382.py:164: UserWarning: You have not specified a value for the `type` parameter. Defaulting to the 'tuples' format for chatbot messages, but this is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style dictionaries with 'role' and 'content' keys.
#   chatbot = gr.Chatbot(height=400)
# /tmp/ipykernel_4045/1383457382.py:164: DeprecationWarning: The default value of 'allow_tags' in gr.Chatbot will be changed from False to True in Gradio 6.0. You will need to explicitly set allow_tags=False if you want to disable tags in your chatbot.
#   chatbot = gr.Chatbot(height=400)
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://00d8147dbb3549a48c.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://00d8147dbb3549a48c.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# SCENARIO: “AI Banking Assistant with Role-Based Access”
# Background Story

# A bank builds an AI assistant to help users:

# Check account balance
# View transactions
# Approve loans
# Manage customer accounts

# But not everyone can do everything

# Roles in the Bank
# Role	Description
# Customer	Bank account holder
# Employee	Bank staff
# Manager	Branch manager
# Permissions (RBAC)
# Action	Customer	Employee	Manager
# View own balance	✅	✅	✅
# View others' accounts	❌	✅	✅
# Approve loan	❌	❌	✅
# View all transactions	❌	✅	✅


# ======================================
# STEP 1: Load API Key from Colab Secrets
# ======================================
from google.colab import userdata

groq_api_key = userdata.get("token")

if not groq_api_key:
    raise ValueError(" GROQ_API_KEY not found in Colab Secrets")

from groq import Groq
client = Groq(api_key=groq_api_key)


# ======================================
# STEP 2: Dummy Bank Database
# ======================================
accounts = {
    "1001": {"name": "Amit", "balance": 50000},
    "1002": {"name": "Neha", "balance": 75000}
}


# ======================================
# STEP 3: Tool Functions (APIs)
# ======================================
def get_balance(account_id):
    if account_id in accounts:
        return f" Balance of {account_id}: ₹{accounts[account_id]['balance']}"
    return " Account not found"


def approve_loan(account_id):
    if account_id in accounts:
        return f" Loan approved for account {account_id}"
    return " Account not found"


# ======================================
# STEP 4: RBAC Security Layer
# ======================================
def secure_access(role, user_account, requested_account, action):

    # Manager → full access
    if role == "manager":
        return True

    # Employee → can view all but cannot approve loans
    elif role == "employee":
        if action == "approve_loan":
            return False
        return True

    # Customer → only own account, no loan approval
    elif role == "customer":
        return user_account == requested_account and action != "approve_loan"

    return False


# ======================================
# STEP 5: MCP Tool Decision via LLM
# ======================================
def decide_action(query):
    try:
        prompt = f"""
        You are an AI banking assistant.

        Decide which action to take:
        - get_balance
        - approve_loan

        Rules:
        - Balance related queries → get_balance
        - Loan approval queries → approve_loan

        Return ONLY the action name.

        Query: {query}
        """

        response = client.chat.completions.create(
            model="llama-3.3-70b-versatile",
            messages=[{"role": "user", "content": prompt}]
        )

        action = response.choices[0].message.content.strip().lower()
        return action

    except Exception as e:
        print(" Groq Error:", e)
        return "fallback"


# ======================================
# STEP 6: MCP Agent (Core Logic)
# ======================================
def banking_agent(message, role, user_account, requested_account, history):

    # Input validation
    if not user_account:
        response = " Please enter your account ID"
        history.append((message, response))
        return "", history

    if not requested_account:
        requested_account = user_account  # default to own account

    # Step 1: LLM decides action
    action = decide_action(message)

    # Step 2: RBAC Security Check
    if not secure_access(role, user_account, requested_account, action):
        response = " Access Denied: You are not authorized"

    else:
        # Step 3: Tool Invocation
        if "balance" in action:
            response = get_balance(requested_account)

        elif "loan" in action:
            response = approve_loan(requested_account)

        # Fallback if LLM fails
        elif action == "fallback":
            msg_lower = message.lower()
            if "balance" in msg_lower:
                response = get_balance(requested_account)
            elif "loan" in msg_lower:
                response = approve_loan(requested_account)
            else:
                response = " Could not understand request"

        else:
            response = " Try asking about balance or loan"

    # Save chat history
    history.append((message, response))

    return "", history


# ======================================
# STEP 7: Gradio UI
# ======================================
import gradio as gr

with gr.Blocks() as demo:

    gr.Markdown("#  AI Banking Assistant (MCP + RBAC + Groq)")

    role = gr.Dropdown(
        ["customer", "employee", "manager"],
        label="Select Role"
    )

    user_account = gr.Textbox(label="Your Account ID (e.g., 1001)")
    requested_account = gr.Textbox(label="Target Account ID (optional)")

    chatbot = gr.Chatbot(height=400)
    msg = gr.Textbox(label="Ask your question")

    state = gr.State([])

    msg.submit(
        banking_agent,
        inputs=[msg, role, user_account, requested_account, state],
        outputs=[msg, chatbot]
    )


# ======================================
# STEP 8: Launch App
# ======================================
demo.launch(share=True)
# Out:
# /tmp/ipykernel_4045/715284819.py:185: UserWarning: You have not specified a value for the `type` parameter. Defaulting to the 'tuples' format for chatbot messages, but this is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style dictionaries with 'role' and 'content' keys.
#   chatbot = gr.Chatbot(height=400)
# /tmp/ipykernel_4045/715284819.py:185: DeprecationWarning: The default value of 'allow_tags' in gr.Chatbot will be changed from False to True in Gradio 6.0. You will need to explicitly set allow_tags=False if you want to disable tags in your chatbot.
#   chatbot = gr.Chatbot(height=400)
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://63544dafb564fd4644.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://63544dafb564fd4644.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# SCENARIO: “University Smart Assistant with Role-Based Access”
# Background Story
# A university deploys an AI-powered academic assistant to help students, faculty, and administrators.
# Users can ask:
# - “What is my attendance record?”
# - “Show me my exam results.”
# - “Update course schedules.”
# - “Approve new course registrations.”
# But not everyone can do everything — access depends on roles.


# ======================================
# STEP 1: Load API Key
# ======================================
from google.colab import userdata
from groq import Groq

groq_api_key = userdata.get("token")
client = Groq(api_key=groq_api_key)


# ======================================
# STEP 2: DATABASE
# ======================================
students = {
    "101": {"name": "Rahul", "attendance": 85, "marks": 78},
    "102": {"name": "Priya", "attendance": 92, "marks": 88}
}


# ======================================
# STEP 3: TOOL FUNCTIONS
# ======================================
def get_own_attendance(user_id):
    return f" Your Attendance: {students[user_id]['attendance']}%"


def get_any_attendance(target_id):
    return f" Attendance of {target_id}: {students[target_id]['attendance']}%"


def update_results(target_id):
    return f" Results updated for {target_id}"


def approve_course():
    return " Course change approved"


def view_all_records():
    data = ""
    for sid, info in students.items():
        data += f"{sid} → {info}\n"
    return " All Student Records:\n" + data


# ======================================
# STEP 4: RBAC SECURITY (MATCH IMAGE)
# ======================================
def secure_access(role, user_id, target_id, action):

    # STUDENT RULES
    if role == "student":
        if action == "view_own_attendance":
            return user_id == target_id
        return False

    # FACULTY RULES
    elif role == "faculty":
        if action in ["view_own_attendance", "view_any_attendance", "update_results", "view_all"]:
            return True
        return False

    # ADMIN RULES
    elif role == "admin":
        return True

    return False


# ======================================
# STEP 5: LLM DECISION
# ======================================
def decide_action(query):

    prompt = f"""
    You are a university assistant.

    Choose ONE action:
    - view_own_attendance
    - view_any_attendance
    - update_results
    - approve_course
    - view_all

    Rules:
    - "my attendance" → view_own_attendance
    - "other student attendance" → view_any_attendance
    - "update result" → update_results
    - "approve course" → approve_course
    - "all records" → view_all

    Return ONLY action.

    Query: {query}
    """

    response = client.chat.completions.create(
        model="llama-3.3-70b-versatile",
        messages=[{"role": "user", "content": prompt}],
        temperature=0
    )

    return response.choices[0].message.content.strip().lower()


# ======================================
# STEP 6: MCP AGENT
# ======================================
def university_agent(message, role, user_id, target_id, history):

    if not user_id:
        history.append((message, " Enter your ID"))
        return "", history

    if not target_id:
        target_id = user_id

    action = decide_action(message)

    # SECURITY CHECK
    if not secure_access(role, user_id, target_id, action):
        response = " Access Denied"

    else:
        # TOOL EXECUTION
        if action == "view_own_attendance":
            response = get_own_attendance(user_id)

        elif action == "view_any_attendance":
            response = get_any_attendance(target_id)

        elif action == "update_results":
            response = update_results(target_id)

        elif action == "approve_course":
            response = approve_course()

        elif action == "view_all":
            response = view_all_records()

        else:
            response = " Try again"

    history.append((message, response))
    return "", history


# ======================================
# STEP 7: GRADIO UI
# ======================================
import gradio as gr

with gr.Blocks() as demo:

    gr.Markdown("#  University Assistant (RBAC + MCP + LLM)")

    role = gr.Dropdown(["student", "faculty", "admin"], label="Select Role")

    user_id = gr.Textbox(label="Your ID (101 / 102)")
    target_id = gr.Textbox(label="Target Student ID (optional)")

    chatbot = gr.Chatbot(height=400)
    msg = gr.Textbox(label="Ask your question")

    state = gr.State([])

    msg.submit(
        university_agent,
        inputs=[msg, role, user_id, target_id, state],
        outputs=[msg, chatbot]
    )


# ======================================
# STEP 8: LAUNCH
# ======================================
demo.launch(share=True)
# Out:
# /tmp/ipykernel_4045/739029758.py:173: UserWarning: You have not specified a value for the `type` parameter. Defaulting to the 'tuples' format for chatbot messages, but this is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style dictionaries with 'role' and 'content' keys.
#   chatbot = gr.Chatbot(height=400)
# /tmp/ipykernel_4045/739029758.py:173: DeprecationWarning: The default value of 'allow_tags' in gr.Chatbot will be changed from False to True in Gradio 6.0. You will need to explicitly set allow_tags=False if you want to disable tags in your chatbot.
#   chatbot = gr.Chatbot(height=400)
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://2dcb66356ee35efc25.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://2dcb66356ee35efc25.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# SCENARIO: “Retail Smart Assistant with Role-Based Access”
# Background Story
# A large retail chain introduces an AI-powered store assistant to streamline operations.
# Users can ask:
# - “What is my purchase history?”
# - “Check inventory for product X.”
# - “Approve supplier orders.”
# - “Manage employee schedules.”
# But not everyone can do everything — access depends on roles.


# ======================================
# STEP 1: Load API Key
# ======================================
from google.colab import userdata
from groq import Groq

groq_api_key = userdata.get("token")
client = Groq(api_key=groq_api_key)


# ======================================
# STEP 2: DATABASE
# ======================================
customers = {
    "501": {"name": "Amit", "purchases": ["Shoes", "T-shirt"]},
    "502": {"name": "Neha", "purchases": ["Bag", "Watch"]}
}

inventory = {
    "Shoes": 20,
    "T-shirt": 50,
    "Bag": 15,
    "Watch": 10
}


# ======================================
# STEP 3: TOOL FUNCTIONS
# ======================================
def view_own_purchases(user_id):
    return f"🛒 Your Purchases: {customers[user_id]['purchases']}"


def view_all_purchases():
    return f"🧾 All Purchases: {customers}"


def check_inventory(product):
    return f" {product} Stock: {inventory.get(product, 'Not Found')}"


def approve_supplier():
    return " Supplier order approved"


def manage_schedule():
    return " Employee schedules updated"


# ======================================
# STEP 4: RBAC SECURITY (MATCH IMAGE)
# ======================================
def secure_access(role, user_id, target_id, action):

    # CUSTOMER
    if role == "customer":
        if action == "view_own":
            return user_id == target_id
        return False

    # STAFF
    elif role == "staff":
        if action in ["view_own", "view_all", "inventory"]:
            return True
        return False

    # MANAGER
    elif role == "manager":
        return True

    return False


# ======================================
# STEP 5: LLM DECISION
# ======================================
def decide_action(query):

    prompt = f"""
    You are a retail assistant.

    Choose ONE action:
    - view_own
    - view_all
    - inventory
    - approve_supplier
    - manage_schedule

    Rules:
    - my purchase → view_own
    - others purchase → view_all
    - inventory/stock → inventory
    - approve supplier → approve_supplier
    - schedule → manage_schedule

    Return ONLY action.

    Query: {query}
    """

    response = client.chat.completions.create(
        model="llama-3.3-70b-versatile",
        messages=[{"role": "user", "content": prompt}],
        temperature=0
    )

    return response.choices[0].message.content.strip().lower()


# ======================================
# STEP 6: MCP AGENT
# ======================================
def retail_agent(message, role, user_id, target_id, product, history):

    if not user_id:
        history.append((message, " Enter User ID"))
        return "", history

    if not target_id:
        target_id = user_id

    action = decide_action(message)

    # RBAC CHECK
    if not secure_access(role, user_id, target_id, action):
        response = " Access Denied"

    else:
        # TOOL EXECUTION
        if action == "view_own":
            response = view_own_purchases(user_id)

        elif action == "view_all":
            response = view_all_purchases()

        elif action == "inventory":
            response = check_inventory(product)

        elif action == "approve_supplier":
            response = approve_supplier()

        elif action == "manage_schedule":
            response = manage_schedule()

        else:
            response = " Try again"

    history.append((message, response))
    return "", history


# ======================================
# STEP 7: GRADIO UI
# ======================================
import gradio as gr

with gr.Blocks() as demo:

    gr.Markdown("#  Retail Assistant (RBAC + MCP + LLM)")

    role = gr.Dropdown(["customer", "staff", "manager"], label="Select Role")

    user_id = gr.Textbox(label="Your ID (501 / 502)")
    target_id = gr.Textbox(label="Target ID (optional)")
    product = gr.Textbox(label="Product (for inventory check)")

    chatbot = gr.Chatbot(height=400)
    msg = gr.Textbox(label="Ask your question")

    state = gr.State([])

    msg.submit(
        retail_agent,
        inputs=[msg, role, user_id, target_id, product, state],
        outputs=[msg, chatbot]
    )


# ======================================
# STEP 8: LAUNCH
# ======================================
demo.launch(share=True)
# Out:
# /tmp/ipykernel_4045/4153264997.py:178: UserWarning: You have not specified a value for the `type` parameter. Defaulting to the 'tuples' format for chatbot messages, but this is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style dictionaries with 'role' and 'content' keys.
#   chatbot = gr.Chatbot(height=400)
# /tmp/ipykernel_4045/4153264997.py:178: DeprecationWarning: The default value of 'allow_tags' in gr.Chatbot will be changed from False to True in Gradio 6.0. You will need to explicitly set allow_tags=False if you want to disable tags in your chatbot.
#   chatbot = gr.Chatbot(height=400)
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://1f02825f3391e27aab.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://1f02825f3391e27aab.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# !pip install groq nest_asyncio
# Out:
# Requirement already satisfied: groq in /usr/local/lib/python3.12/dist-packages (1.1.2)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.12/dist-packages (1.6.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from groq) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from groq) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /usr/local/lib/python3.12/dist-packages (from groq) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->groq) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (0.4.2)

# %%
# SCENARIO: “Corporate Research Assistant System”
# Background Story
# A multinational company deploys an AI-powered business intelligence assistant.
# Employees can ask:
# - “What’s the latest news about Tesla?”
# - “What’s Tesla’s current stock price?”
# - “Give me a company profile instantly.”
# Instead of manually searching news sites, finance portals, and HR databases,
# AI fetches all the data in parallel, analyzes it, and generates a professional report.

# How it works (mapped to your pipeline):
# - Parallel Data Collection → AI gathers news, stock prices, and company profiles simultaneously.
# - LLM Analysis → AI interprets the combined data, highlighting key insights.
# - Report Generation → AI produces a polished, executive-ready report.

# Impact:
# - Saves analysts hours of manual research.
# - Provides real-time, consolidated insights for decision-making.
# - Empowers managers with instant reports for board meetings or investor updates.


# ======================================K
# STEP 1: Load Groq API Key (Colab Secret)
# ======================================
from google.colab import userdata
groq_api_key = userdata.get("token")

from groq import Groq
client = Groq(api_key=groq_api_key)


# ======================================
# STEP 2: MOCK TOOLS (Simulating MCP Tools)
# ======================================

import asyncio
import random
import nest_asyncio

# Apply nest_asyncio to allow nested event loops
nest_asyncio.apply()

async def web_search(query):
    await asyncio.sleep(1)  # simulate delay
    return f" News about {query}: Market is growing fast."

async def get_stock_data(company):
    await asyncio.sleep(1)
    price = random.randint(100, 500)
    return f" Stock price of {company}: ${price}"

async def fetch_company_profile(company):
    await asyncio.sleep(1)
    return f" {company} has 5000 employees, HQ in USA"


# ======================================
# STEP 3: PARALLEL TOOL INVOCATION
# ======================================

async def parallel_research(company):

    results = await asyncio.gather(
        web_search(company),
        get_stock_data(company),
        fetch_company_profile(company),
        return_exceptions=True
    )

    news, stock, profile = results

    return {
        "news": news if not isinstance(news, Exception) else "News unavailable",
        "stock": stock if not isinstance(stock, Exception) else "Stock unavailable",
        "profile": profile if not isinstance(profile, Exception) else "Profile unavailable"
    }


# ======================================
# STEP 4: CHAINED TOOL INVOCATION USING GROQ
# ======================================

def analyse_text(text):
    response = client.chat.completions.create(
    model="llama-3.3-70b-versatile", # Updated model name to a currently available Groq model
        messages=[{
            "role": "user",
            "content": f"Analyze this data and give key insights:\n{text}"
        }]
    )
    return response.choices[0].message.content


def generate_report(analysis, company):
    response = client.chat.completions.create(
        model="llama-3.3-70b-versatile", # Updated model name to a currently available Groq model
        messages=[{
            "role": "user",
            "content": f"Create a professional report for {company}:\n{analysis}"
        }]
    )
    return response.choices[0].message.content


# ======================================
# STEP 5: FULL MCP PIPELINE
# ======================================

async def full_pipeline(company):

    # Step 1: Parallel Data Collection
    data = await parallel_research(company)

    combined_text = f"""
    News: {data['news']}
    Stock: {data['stock']}
    Profile: {data['profile']}
    """

    # Step 2: Analysis (LLM)
    analysis = analyse_text(combined_text)

    # Step 3: Report Generation (LLM)
    report = generate_report(analysis, company)

    return report


# ======================================
# STEP 6: RUN THE SYSTEM
# ======================================

company_name = "Tesla"

# Use asyncio.run() after applying nest_asyncio
result = asyncio.run(full_pipeline(company_name))

print(" FINAL REPORT:\n")
print(result)
# Out:
#  FINAL REPORT:
#
# **Tesla Company Report**
#
# **Executive Summary**
#
# This report provides a comprehensive analysis of Tesla, a leading player in the electric vehicle and renewable energy industry. Based on the provided data, our key findings indicate a positive market trend, strong stock performance, and a competitive company size and location. We identify potential opportunities for revenue growth and market expansion, as well as potential risks associated with increased competition and internal operational challenges.
#
# **Market Analysis**
#
# The current market trend suggests a significant growth in demand for electric vehicles, renewable energy solutions, and other products and services offered by Tesla. This growth presents a positive outlook for the company, with potential opportunities for increased revenue and market share. However, it's essential to consider the broader market trends and competitive landscape to ensure Tesla remains competitive.
#
# **Financial Performance**
#
# The current stock price of Tesla is $304, which may indicate a strong financial health and investor confidence. However, without historical data or comparative analysis, it's challenging to determine if this is a high or low price point. Further analysis of the company's financial performance, including revenue growth, profit margins, and cash flow, is necessary to gain a comprehensive understanding of Tesla's financial position.
#
# **Company Overview**
#
# Tesla is a medium to large-sized company with 5000 employees, indicating a significant presence in the industry. The company's headquarters is located in the USA, which may provide a competitive advantage in the North American market. This location could enable Tesla to expand its customer base, increase its market share, and leverage local resources and expertise.
#
# **Opportunities and Risks**
#
# Our analysis identifies the following potential opportunities and risks:
#
# **Opportunities:**
#
# 1. **Market Growth**: The growing market trend could lead to increased demand for Tesla's products and services, resulting in potential revenue growth.
# 2. **Competitive Advantage**: The company's size and HQ location could provide a competitive advantage in the US market, allowing Tesla to expand its customer base and increase its market share.
#
# **Risks:**
#
# 1. **Increased Competition**: Rapid market growth can lead to increased competition, which may put pressure on Tesla's market share and pricing strategy.
# 2. **Operational Challenges**: As a company with 5000 employees, Tesla may face challenges in maintaining its corporate culture, managing employee expectations, and ensuring efficient operations.
#
# **Conclusion**
#
# In conclusion, our analysis suggests that Tesla is a growing company with a strong presence in the US market, and potentially poised for further expansion. However, it's essential to consider the broader market trends, competitive landscape, and internal factors to gain a comprehensive understanding of the company's prospects. We recommend further analysis of Tesla's financial performance, market trends, and competitive landscape to ensure the company remains competitive and capitalizes on potential opportunities.
#
# **Recommendations**
#
# 1. **Conduct a comprehensive market analysis** to gain a deeper understanding of the competitive landscape and market trends.
# 2. **Analyze financial performance** to determine Tesla's financial health and identify areas for improvement.
# 3. **Develop strategies to address operational challenges** and maintain a strong corporate culture.
# 4. **Monitor and respond to changes in the market** to ensure Tesla remains competitive and capitalizes on potential opportunities.
#
# By following these recommendations, Tesla can continue to grow and thrive in the electric vehicle and renewable energy industry.

# %%
# SCENARIO: “Healthcare Research Assistant System”
# Background Story
# A medical research institute deploys an AI-powered clinical intelligence assistant.
# Researchers and doctors can ask:
# • 	“What’s the latest research on diabetes treatments?”
# • 	“Summarize recent clinical trial results for cancer drugs.”
# • 	“Give me a profile of a pharmaceutical company instantly.”
# Instead of manually searching journals, trial databases, and company reports,
# AI fetches all the data in parallel, analyzes it, and generates a professional research summary.

# How it works (mapped to your pipeline):
# • 	Parallel Data Collection → AI gathers medical news, trial results, and company profiles simultaneously.
# • 	LLM Analysis → AI interprets the combined data, highlighting key medical insights.
# • 	Report Generation → AI produces a polished, researcher-ready report.

# ======================================
# STEP 1: Load Groq API Key (Colab Secret)
# ======================================
from google.colab import userdata
groq_api_key = userdata.get("token")

from groq import Groq
client = Groq(api_key=groq_api_key)


# ======================================
# STEP 2: MOCK TOOLS (Healthcare MCP Tools)
# ======================================
import asyncio
import random
import nest_asyncio

nest_asyncio.apply()

#  Medical News
async def get_medical_news(topic):
    await asyncio.sleep(1)
    return f" Latest news on {topic}: Breakthrough treatments emerging."

#  Clinical Trials
async def get_clinical_trials(topic):
    await asyncio.sleep(1)
    return f" Clinical trials show improved outcomes for {topic} patients."

#  Pharma Company Info
async def get_pharma_profile(company):
    await asyncio.sleep(1)
    return f" {company} is a leading pharma company working on innovative drugs."


# ======================================
# STEP 3: PARALLEL TOOL INVOCATION
# ======================================
async def parallel_research(topic, company):

    results = await asyncio.gather(
        get_medical_news(topic),
        get_clinical_trials(topic),
        get_pharma_profile(company),
        return_exceptions=True
    )

    news, trials, profile = results

    return {
        "news": news if not isinstance(news, Exception) else "News unavailable",
        "trials": trials if not isinstance(trials, Exception) else "Trials unavailable",
        "profile": profile if not isinstance(profile, Exception) else "Profile unavailable"
    }


# ======================================
# STEP 4: LLM ANALYSIS (GROQ)
# ======================================
def analyse_text(text):
    response = client.chat.completions.create(
        model="llama-3.3-70b-versatile",
        messages=[{
            "role": "user",
            "content": f"Analyze this medical data and give key insights:\n{text}"
        }]
    )
    return response.choices[0].message.content


# ======================================
# STEP 5: REPORT GENERATION (GROQ)
# ======================================
def generate_report(analysis, topic):
    response = client.chat.completions.create(
        model="llama-3.3-70b-versatile",
        messages=[{
            "role": "user",
            "content": f"Create a professional healthcare research report on {topic}:\n{analysis}"
        }]
    )
    return response.choices[0].message.content


# ======================================
# STEP 6: FULL MCP PIPELINE
# ======================================
async def full_pipeline(topic, company):

    # Step 1: Parallel Data Collection
    data = await parallel_research(topic, company)

    combined_text = f"""
    Medical News: {data['news']}
    Clinical Trials: {data['trials']}
    Pharma Company: {data['profile']}
    """

    # Step 2: LLM Analysis
    analysis = analyse_text(combined_text)

    # Step 3: Report Generation
    report = generate_report(analysis, topic)

    return report


# ======================================
# STEP 7: RUN THE SYSTEM
# ======================================
topic = "diabetes"
company = "Pfizer"

result = asyncio.run(full_pipeline(topic, company))

print(" FINAL HEALTHCARE REPORT:\n")
print(result)
# Out:
#  FINAL HEALTHCARE REPORT:
#
# **Diabetes Research Report: Emerging Trends and Future Implications**
#
# **Executive Summary:**
# This report provides an in-depth analysis of the latest developments in diabetes research, highlighting emerging breakthrough treatments, improved outcomes, and the pharmaceutical industry's commitment to addressing this significant health issue. The report also explores the potential impact of these advancements on the quality of life for diabetes patients and the future implications for stakeholders.
#
# **Introduction:**
# Diabetes is a chronic and debilitating disease that affects millions of people worldwide. The management and treatment of diabetes have traditionally focused on glucose control, lifestyle modifications, and medication. However, recent advances in medical research have led to the development of innovative treatments that may revolutionize the management and treatment of diabetes.
#
# **Key Insights from the Medical Data:**
#
# 1. **Emerging Breakthrough Treatments:** Recent clinical trials have demonstrated the efficacy of new and innovative treatments, including novel insulin therapies, glucagon-like peptide-1 (GLP-1) receptor agonists, and sodium-glucose cotransporter 2 (SGLT2) inhibitors. These treatments have shown promise in improving glycemic control, reducing complications, and enhancing patient outcomes.
# 2. **Improved Outcomes:** Clinical trials have consistently demonstrated improved outcomes for diabetes patients, including reduced hemoglobin A1c (HbA1c) levels, decreased blood pressure, and improved lipid profiles. These findings suggest that the new treatments are effective and can lead to better health outcomes.
# 3. **Pharmaceutical Industry Involvement:** Leading pharmaceutical companies, such as Pfizer, are actively working on developing innovative drugs for diabetes. This industry commitment is a positive sign, as it indicates a significant investment in research and development to address this significant health issue.
# 4. **Potential Impact:** The emergence of new treatments and improved outcomes could have a substantial impact on the quality of life for diabetes patients. Potential benefits include reduced complications, improved management, and increased life expectancy.
# 5. **Research and Development:** The fact that clinical trials are showing improved outcomes suggests that significant research and development efforts are being made to combat diabetes. This is a positive sign for patients and healthcare professionals, as it indicates a commitment to advancing diabetes research and developing effective treatments.
#
# **Future Implications:**
# The emerging trends and breakthroughs in diabetes research have significant implications for the future of diabetes management and treatment. Potential future implications include:
#
# * **Increased investment in diabetes research and development:** The pharmaceutical industry's commitment to addressing diabetes is likely to lead to increased investment in research and development, driving innovation and advancements in treatment options.
# * **Potential for new treatments to become available in the market:** The development of new treatments and therapies is likely to lead to a wider range of options for diabetes patients, potentially improving health outcomes and quality of life.
# * **Improved health outcomes for diabetes patients:** The emergence of new treatments and improved outcomes is likely to lead to better health outcomes for diabetes patients, including reduced complications and improved management.
# * **Enhanced quality of life for individuals living with diabetes:** The potential benefits of new treatments and improved outcomes could lead to an enhanced quality of life for individuals living with diabetes, including increased life expectancy and reduced disability.
# * **Potential reduction in healthcare costs associated with diabetes management:** The development of new treatments and improved outcomes could lead to a reduction in healthcare costs associated with diabetes management, including reduced hospitalization rates and improved patient outcomes.
#
# **Recommendations for Stakeholders:**
#
# * **Patients:** Stay informed about emerging treatments and consult with healthcare professionals about potential new options. Patients should also be aware of the importance of adherence to treatment plans and lifestyle modifications to optimize health outcomes.
# * **Healthcare Professionals:** Stay up-to-date with the latest research and clinical trials to provide the best possible care for diabetes patients. Healthcare professionals should also be aware of the potential benefits and limitations of new treatments and therapies.
# * **Pharmaceutical Companies:** Continue to invest in research and development to bring innovative treatments to market. Pharmaceutical companies should also prioritize patient-centered research and development, focusing on treatments that address the needs and concerns of diabetes patients.
# * **Researchers:** Collaborate with pharmaceutical companies and healthcare professionals to advance diabetes research and develop effective treatments. Researchers should also prioritize patient-centered research and development, focusing on treatments that address the needs and concerns of diabetes patients.
#
# **Conclusion:**
# The emerging trends and breakthroughs in diabetes research have significant implications for the future of diabetes management and treatment. The development of new treatments and improved outcomes is likely to lead to better health outcomes, enhanced quality of life, and reduced healthcare costs associated with diabetes management. Stakeholders, including patients, healthcare professionals, pharmaceutical companies, and researchers, must work together to advance diabetes research and develop effective treatments that address the needs and concerns of diabetes patients.
